# %% [markdown]
# # Project Notebook

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from openpyxl import load_workbook

# %% [markdown]
# # 1. Import Datasets

# %%
# main data set
data_main = pd.read_csv('data/cancer_reg.csv', encoding = "ISO-8859-1")

# import data of manufactoring share
wb = load_workbook('data/industry_county_data_overview.xlsx', data_only=True)
ws = wb['new_overview']
ws_data = ws.values
# Get the first line in file as a header line
columns = next(ws_data)[0:]
# Create a DataFrame based on the second and subsequent lines of data
data_industry = pd.DataFrame(ws_data, columns=columns)

# import data of UV exposure
data_uv = pd.read_csv('data/uv-county.csv', encoding = "ISO-8859-1")

# import data with rural/urban classification
data_county_class = pd.read_excel('data/PctUrbanRural_County.xls', sheet_name='Pct urban by county')

# %%
# Reduce DataFrame to most important columns
data_industry = data_industry[['county_state', 'Industry Share of County GDP (Manufacturing)', 'Industry Share of County GDP (Mining, Oil, Gas)']]
data_industry
# Out:
#        county_state Industry Share of County GDP (Manufacturing)  \
# 0        Autauga_AL                                      0.15095
# 1        Baldwin_AL                                     0.068274
# 2        Barbour_AL                                     0.261618
# 3           Bibb_AL                                     0.119731
# 4         Blount_AL                                      0.12457
# ...             ...                                          ...
# 3112  Sweetwater_WY                                     0.110247
# 3113       Teton_WY                                     0.009897
# 3114       Uinta_WY                                     0.041912
# 3115    Washakie_WY                                     0.153798
# 3116      Weston_WY                                            0
#
#      Industry Share of County GDP (Mining, Oil, Gas)
# 0                                           0.019244
# 1                                           0.002761
# 2                                           0.088787
# 3                                           0.030386
# 4                                           0.004438
# ...                                              ...
# 3112                                        0.433276
# 3113                                        0.003029
# 3114                                        0.102798
# 3115                                        0.048576
# 3116                                        0.133874
#
# [3117 rows x 3 columns]

# %% [markdown]
# # 2. Data Cleaning
# ## 2.1 Harmonize county names

# %% [markdown]
# ### Lower case for all column names

# %%
data_main.columns=[item.lower() for item in data_main.columns]
data_industry.columns=[item.lower() for item in data_industry.columns]
data_uv.columns=[item.lower() for item in data_uv.columns]
data_county_class.columns=[item.lower() for item in data_county_class]

# %%
#data_main.geography.to_csv('county_check.csv')

# %%
# Extract county name from Geography

def get_countyname(item):
    if ' County' in item:
        return item[:item.find(' County')]
    elif ' Parish' in item:
        return item[:item.find(' Parish')]
    #elif ' city' in item:
    #    return item[:item.find(' city')]
    else:
        return item[:item.find(',')]

data_main['county'] =  data_main.geography.apply(get_countyname)
# Extract state name from Geography
data_main['state'] = data_main.geography.str.split(', ').str[1]

# %%
data_main.state
# Out:
# 0       Washington
# 1       Washington
# 2       Washington
# 3       Washington
# 4       Washington
#            ...
# 3042        Kansas
# 3043        Kansas
# 3044        Kansas
# 3045        Kansas
# 3046        Kansas
# Name: state, Length: 3047, dtype: object

# %%
# read state abbreviation lookup table
wb2 = load_workbook('data/state_abbreviations.xlsx')
ws2 = wb2['Sheet1']
ws_data2 = ws2.values
# Get the first line in file as a header line
columns2 = next(ws_data2)[0:]
# Create a DataFrame based on the second and subsequent lines of data
state_abb = pd.DataFrame(ws_data2, columns=columns2)

# %%
state_abb.head()
# Out:
#             state state_short
# 0         ALABAMA          AL
# 1          ALASKA          AK
# 2  AMERICAN SAMOA          AS
# 3         ARIZONA          AZ
# 4        ARKANSAS          AR

# %%
# capitalize state names in lookup table
state_abb.state = state_abb.state.str.title()
# Correct this for DC
state_abb.state = state_abb.state.str.replace('District Of Columbia','District of Columbia')

# %% [markdown]
# ### Merge main table with lookup table

# %%
# merge
data_main = pd.merge(data_main, state_abb, how='left', on='state')

# %%
print(sorted(data_main.state.unique()))
print(sorted(state_abb.state.unique()))
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
# ['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Northern Mariana Is', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virgin Islands', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %% [markdown]
# ### Create new column which consists of county and state name

# %%
# New combined column
data_main['county_state'] = data_main['county'].map(str) + '_' + data_main['state_short'].map(str)
data_main.county_state
# Out:
# 0          Kitsap_WA
# 1        Kittitas_WA
# 2       Klickitat_WA
# 3           Lewis_WA
# 4         Lincoln_WA
#             ...
# 3042    Ellsworth_KS
# 3043       Finney_KS
# 3044         Ford_KS
# 3045     Franklin_KS
# 3046        Geary_KS
# Name: county_state, Length: 3047, dtype: object

# %%
# check for duplicates
data_main.county_state[data_main.county_state.duplicated(keep=False) == True]
# Out:
# Series([], Name: county_state, dtype: object)

# %% [markdown]
# ### Harmonize data_industry table

# %%
data_industry.head()
# Out:
#   county_state industry share of county gdp (manufacturing)  \
# 0   Autauga_AL                                      0.15095
# 1   Baldwin_AL                                     0.068274
# 2   Barbour_AL                                     0.261618
# 3      Bibb_AL                                     0.119731
# 4    Blount_AL                                      0.12457
#
#   industry share of county gdp (mining, oil, gas)
# 0                                        0.019244
# 1                                        0.002761
# 2                                        0.088787
# 3                                        0.030386
# 4                                        0.004438

# %%
# kick out asterisks and (independent city from county)
data_industry.county_state = data_industry.county_state.str.replace(', ','_', regex=False)
data_industry.county_state = data_industry.county_state.str.replace('*','', regex=False)
data_industry.county_state = data_industry.county_state.str.replace('(Independent City)','city', regex=False)
data_industry.county_state = data_industry.county_state.str.replace('(city)','city', regex=False)
# rename columns
data_industry.rename(columns={"industry share of county gdp (manufacturing)": "industry_share_manufacturing", "industry share of county gdp (mining, oil, gas)": "industry_share_mineoilgas"}, inplace=True)

# %% [markdown]
# ### Harmonize data_uv table

# %%
data_uv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3108 entries, 0 to 3107
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   statename    3108 non-null   object
#  1   state_abr    3108 non-null   object
#  2   county_fips  3108 non-null   int64
#  3   county name  3108 non-null   object
#  4   uv_ wh/m_    3108 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 121.5+ KB

# %%
# Create new Column county_state
data_uv['county_state'] = data_uv['county name'].map(str) + '_' + data_uv['state_abr'].map(str)
data_uv['county_state']
# Out:
# 0          Autauga_AL
# 1          Baldwin_AL
# 2          Barbour_AL
# 3             Bibb_AL
# 4           Blount_AL
#             ...
# 3103    Sweetwater_WY
# 3104         Teton_WY
# 3105         Uinta_WY
# 3106      Washakie_WY
# 3107        Weston_WY
# Name: county_state, Length: 3108, dtype: object

# %%
# Rename column
data_uv.rename(columns={"uv_ wh/m_": "uv"}, inplace=True)

# dropping unnessessary columns
data_uv = data_uv[['county_state','uv']]
data_uv.head()
# Out:
#   county_state    uv
# 0   Autauga_AL  4563
# 1   Baldwin_AL  4492
# 2   Barbour_AL  4642
# 3      Bibb_AL  4499
# 4    Blount_AL  4416

# %% [markdown]
# ### Harmonize data_county_class table

# %%
data_county_class
# Out:
#       state  county    statename countyname  pop_cou    area_cou  pop_urban  \
# 0         1       1      Alabama    Autauga    54571  1539582278      31650
# 1         1       3      Alabama    Baldwin   182265  4117521611     105205
# 2         1       5      Alabama    Barbour    27457  2291818968       8844
# 3         1       7      Alabama       Bibb    22915  1612480789       7252
# 4         1       9      Alabama     Blount    57322  1669961855       5760
# ...     ...     ...          ...        ...      ...         ...        ...
# 3216     72     145  Puerto Rico  Vega Baja    59662   118766810      57170
# 3217     72     147  Puerto Rico    Vieques     9301   131488427       8230
# 3218     72     149  Puerto Rico   Villalba    26073    92298550      22564
# 3219     72     151  Puerto Rico    Yabucoa    37941   143005172      32192
# 3220     72     153  Puerto Rico      Yauco    42043   176615594      34303
#
#       poppct_urban  area_urban  areapct_urban  ...  pop_uc  poppct_uc  \
# 0            58.00    50882539           3.30  ...       0       0.00
# 1            57.72   275001368           6.68  ...   41556      22.80
# 2            32.21    17447656           0.76  ...    8844      32.21
# 3            31.65    18903236           1.17  ...    7252      31.65
# 4            10.05    10874700           0.65  ...    5374       9.38
# ...            ...         ...            ...  ...     ...        ...
# 3216         95.82    72771265          61.27  ...       0       0.00
# 3217         88.49    13439063          10.22  ...    8230      88.49
# 3218         86.54    39316802          42.60  ...       0       0.00
# 3219         84.85    62090343          43.42  ...       0       0.00
# 3220         81.59    41533284          23.52  ...       0       0.00
#
#         area_uc  areapct_uc  popden_uc  pop_rural  poppct_rural  area_rural  \
# 0             0        0.00        NaN      22921         42.00  1488699739
# 1     111381848        2.71      966.3      77060         42.28  3842520243
# 2      17447656        0.76     1312.8      18613         67.79  2274371312
# 3      18903236        1.17      993.6      15663         68.35  1593577553
# 4       9851721        0.59     1412.8      51562         89.95  1659087155
# ...         ...         ...        ...        ...           ...         ...
# 3216          0        0.00        NaN       2492          4.18    45995545
# 3217   13439063       10.22     1586.1       1071         11.51   118049364
# 3218          0        0.00        NaN       3509         13.46    52981748
# 3219          0        0.00        NaN       5749         15.15    80914829
# 3220          0        0.00        NaN       7740         18.41   135082310
#
#       areapct_rural  popden_rural
# 0             96.70          39.9
# 1             93.32          51.9
# 2             99.24          21.2
# 3             98.83          25.5
# 4             99.35          80.5
# ...             ...           ...
# 3216          38.73         140.3
# 3217          89.78          23.5
# 3218          57.40         171.5
# 3219          56.58         184.0
# 3220          76.48         148.4
#
# [3221 rows x 26 columns]

# %%
# drop state column which contains a number
data_county_class.drop('state', axis=1, inplace = True)
# rename the statename column
data_county_class.rename(columns={'statename': 'state'}, inplace=True)

# %%
# merge with abbreviation table
data_county_class = pd.merge(data_county_class, state_abb, how='left', on='state')

# %%
# Create new Column county_state
data_county_class['county_state'] = data_county_class['countyname'].map(str) + '_' + data_county_class['state_short'].map(str)
data_county_class['county_state']
# Out:
# 0         Autauga_AL
# 1         Baldwin_AL
# 2         Barbour_AL
# 3            Bibb_AL
# 4          Blount_AL
#             ...
# 3216    Vega Baja_PR
# 3217      Vieques_PR
# 3218     Villalba_PR
# 3219      Yabucoa_PR
# 3220        Yauco_PR
# Name: county_state, Length: 3221, dtype: object

# %%
# Drop unnessessary columns
data_county_class = data_county_class[['county_state','poppct_urban', 'poppct_rural']]
data_county_class.head()
# Out:
#   county_state  poppct_urban  poppct_rural
# 0   Autauga_AL         58.00         42.00
# 1   Baldwin_AL         57.72         42.28
# 2   Barbour_AL         32.21         67.79
# 3      Bibb_AL         31.65         68.35
# 4    Blount_AL         10.05         89.95

# %%
# Look for duplicates
data_county_class[data_county_class.county_state.duplicated(keep=False)]
# Out:
#       county_state  poppct_urban  poppct_rural
# 1195  Baltimore_MD         93.47          6.53
# 1216  Baltimore_MD        100.00          0.00
# 1578  St. Louis_MO         98.86          1.14
# 1597  St. Louis_MO        100.00          0.00
# 2829    Bedford_VA         21.57         78.43
# 2848    Fairfax_VA         98.61          1.39
# 2852   Franklin_VA         10.77         89.23
# 2895   Richmond_VA          0.00        100.00
# 2896    Roanoke_VA         81.46         18.54
# 2916    Bedford_VA         97.94          2.06
# 2925    Fairfax_VA        100.00          0.00
# 2927   Franklin_VA         96.75          3.25
# 2945   Richmond_VA        100.00          0.00
# 2946    Roanoke_VA         99.99          0.01

# %%
# Manually change the counties that are actually cities
data_county_class.iloc[1216, data_county_class.columns.get_loc('county_state')] = 'Baltimore city_MD'
data_county_class.iloc[1578, data_county_class.columns.get_loc('county_state')] = 'St. Louis city_MO'
data_county_class.iloc[2916, data_county_class.columns.get_loc('county_state')] = 'Bedford city_VA'
data_county_class.iloc[2925, data_county_class.columns.get_loc('county_state')] = 'Fairfax city_VA'
data_county_class.iloc[2927, data_county_class.columns.get_loc('county_state')] = 'Franklin city_VA'
data_county_class.iloc[2945, data_county_class.columns.get_loc('county_state')] = 'Richmond city_VA'
data_county_class.iloc[2946, data_county_class.columns.get_loc('county_state')] = 'Roanoke city_VA'

# %% [markdown]
# ## 2.2 Data Joining

# %% [markdown]
# ### Join data_main with data_industry

# %%
data_main = pd.merge(data_main, data_industry, how='left', on='county_state')

# %%
data_main[(data_main.industry_share_manufacturing.isna() == True)].count
# Out:
# <bound method DataFrame.count of       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 127   1962.667684               145             193.5     453.549422
# 216    309.000000               120             153.3     396.200000
# 225    346.000000               156             176.8     399.000000
# 228    155.000000                59             172.1     437.000000
# 229   1142.000000               407             150.1     373.700000
# 233    493.000000               204             155.9     400.500000
# 234    115.000000                58             159.2     338.000000
# 235    378.000000               157             156.1     400.200000
# 240     97.000000                43             181.8     405.700000
# 241    518.000000               191             172.5     449.400000
# 247    312.000000               136             176.7     420.800000
# 249    176.000000               106             223.4     367.300000
# 251    272.000000               103             152.3     389.300000
# 253     64.000000                58             226.6     265.700000
# 254     46.000000                19             240.8     578.200000
# 255    250.000000                60             178.2     718.900000
# 257    117.000000                43             159.3     493.600000
# 258    320.000000               130             207.4     539.000000
# 259     55.000000                16             137.6     447.700000
# 260     51.000000                25             221.7     468.000000
# 261    120.000000                39             180.3     566.300000
# 263    190.000000                51             150.5     591.100000
# 264    139.000000                65             244.9     547.600000
# 265    391.000000               165             194.5     495.000000
# 266    108.000000                41             155.2     364.100000
# 269     22.000000                 9             197.3     461.000000
# 270    249.000000                88             224.4     651.300000
# 271     67.000000                24             159.2     441.300000
# 273     51.000000                21             193.1     463.100000
# 276    162.000000                63             186.6     511.500000
# 277    181.000000                64             176.1     537.900000
# 280    157.000000                58             210.5     596.900000
# 281    135.000000                23             162.1    1014.200000
# 282    117.000000                59             192.8     401.900000
# 955    425.000000               174             143.8     372.900000
# 956     98.000000                50             189.5     401.800000
# 961    391.000000               163             167.1     408.900000
# 968    267.000000               115             160.1     384.700000
# 970    168.000000                78             172.5     390.600000
# 979    138.000000                60             185.4     414.500000
# 981   3959.000000              1229             126.9     381.800000
# 986    389.000000               157             185.3     456.600000
# 992     69.000000                24             174.7     492.200000
# 2203   142.000000                59             167.5     405.300000
# 2315   734.000000               247             139.9     418.300000
# 2335    53.000000                20             140.9     383.500000
#
#       medincome  popest2015  povertypercent  studypercap           binnedinc  \
# 127       45639       54521            19.3    36.683113    (45201, 48021.6]
# 216       43484       97653            24.8   256.008520    (42724.4, 45201]
# 225       44207       62194            14.6     0.000000    (42724.4, 45201]
# 228       61792       37862            10.5     0.000000   (61494.5, 125635]
# 229       91886      451721             7.2    19.923803   (61494.5, 125635]
# 233       61935       94409             8.2    21.184421   (61494.5, 125635]
# 234       48497       22354            13.0     0.000000  (48021.6, 51046.4]
# 235       55798       78593            11.7     0.000000  (54545.6, 61494.5]
# 240       46521       18109            15.3     0.000000    (45201, 48021.6]
# 241       75714      130475             9.2   176.278981   (61494.5, 125635]
# 247       43353       54591            14.5    36.636076    (42724.4, 45201]
# 249       38528       39718            21.9     0.000000  (37413.8, 40362.7]
# 251       81169       67837             5.5     0.000000   (61494.5, 125635]
# 253       34099       17141            21.8   408.377574    [22640, 34218.1]
# 254       38331        6618            17.2     0.000000  (37413.8, 40362.7]
# 255       45890       46597            25.9   364.830354    (45201, 48021.6]
# 257       52355       17820            11.5     0.000000  (51046.4, 54545.6]
# 258       33646       42082            23.6   356.446937    [22640, 34218.1]
# 259      125635       13892             3.2     0.000000   (61494.5, 125635]
# 260       38583        8490            22.5     0.000000  (37413.8, 40362.7]
# 261       51195       28118            16.8  1280.318657  (51046.4, 54545.6]
# 263       38541       52538            28.3    57.101527  (37413.8, 40362.7]
# 264       40122       22378            19.5     0.000000  (37413.8, 40362.7]
# 265       40065       79812            25.0   388.412770  (37413.8, 40362.7]
# 266       72510       41764             9.8     0.000000   (61494.5, 125635]
# 269       31620        3939            21.6  3046.458492    [22640, 34218.1]
# 270       32749       32477            25.8     0.000000    [22640, 34218.1]
# 271       84213       12059             5.9     0.000000   (61494.5, 125635]
# 273       34267       17403            32.4     0.000000  (34218.1, 37413.8]
# 276       54195       25432            10.2   432.525952  (51046.4, 54545.6]
# 277       42552       24416            16.5     0.000000  (40362.7, 42724.4]
# 280       44843       21491            14.6     0.000000    (42724.4, 45201]
# 281       46954       15052            20.1     0.000000    (45201, 48021.6]
# 282       44537       27284            13.4  1026.242486    (42724.4, 45201]
# 955       67083      105703             9.1   113.525633   (61494.5, 125635]
# 956       45454       15677            15.8   255.150858    (45201, 48021.6]
# 961       57808       74314             9.8    26.912829  (54545.6, 61494.5]
# 968       46663       55086            14.5     0.000000    (45201, 48021.6]
# 970       38474       29724            17.0     0.000000  (37413.8, 40362.7]
# 979       52288       27852            12.1     0.000000  (51046.4, 54545.6]
# 981      110507     1142234             6.7   153.208537   (61494.5, 125635]
# 986       65485       83199             7.7     0.000000   (61494.5, 125635]
# 992       36459       11885            25.1     0.000000  (34218.1, 37413.8]
# 2203      52003       38809            10.9     0.000000  (51046.4, 54545.6]
# 2315      64916      164637            13.1   103.257469   (61494.5, 125635]
# 2335      45578       12819            15.1     0.000000    (45201, 48021.6]
#
#       medianage  ...   pctasian  pctotherrace pctmarriedhouseholds  birthrate  \
# 127        42.6  ...   2.988143      7.250101            42.937853   4.262413
# 216        27.5  ...   6.119191      0.910156            43.444416   3.135414
# 225       546.0  ...   0.342389      1.576584            51.591360   4.194566
# 228        37.1  ...   2.094703      2.070626            61.871735   4.855936
# 229        34.0  ...   7.773898      4.591889            60.213167   6.857756
# 233        43.5  ...   2.851559      0.145248            53.388010   5.404492
# 234        48.3  ...   0.699519      0.770807            53.653826   6.476147
# 235        41.5  ...   0.723790      1.400013            58.197468   4.834403
# 240        45.4  ...   0.103205      0.401955            52.514217   5.455508
# 241        36.7  ...   2.534243      3.814678            61.331527   6.051314
# 247        44.7  ...   0.555160      0.500374            52.008997   5.091597
# 249        39.8  ...   0.471256      0.180113            49.416546   3.651139
# 251        39.5  ...   5.253419      0.559643            64.849773   4.925163
# 253        41.8  ...   0.930153      1.289660            40.541591   3.868375
# 254        33.8  ...   7.095710      0.000000            45.926197  11.887694
# 255        29.8  ...   6.663118      0.310531            30.492339   2.753791
# 257        40.0  ...   3.499857      1.741365            42.696313   3.664122
# 258        41.8  ...   1.220259      1.703180            33.347702   3.236584
# 259        37.7  ...  11.429216      3.554253            53.271390   3.066181
# 260        38.0  ...   0.591226      0.744945            30.842745   4.927099
# 261        29.4  ...   2.474904      3.668553            34.216270   4.269052
# 263        23.5  ...   4.102125      1.181210            34.669998   2.564793
# 264        36.9  ...   1.463261      4.241663            30.507696   5.969290
# 265        28.7  ...   2.844239      0.749763            37.783932   5.960878
# 266        33.3  ...   5.242618      4.440027            56.913054   6.934168
# 269        39.3  ...   5.814824      1.472423            32.641615   3.938224
# 270        39.5  ...   1.319927      1.273231            27.009295   4.372409
# 271        43.8  ...   1.846485      0.389169            62.602327   4.361371
# 273        22.3  ...   1.934690      0.732837            31.130181   1.039130
# 276        40.5  ...   2.074310      0.596066            46.251867   4.609250
# 277        42.3  ...   1.082958      0.632414            40.521806   3.909799
# 280        38.5  ...   0.964539      2.245863            40.803898   7.446378
# 281        24.6  ...   5.889928      0.460892            36.337594   2.181467
# 282        37.0  ...   2.399882      2.723793            38.678356   6.642836
# 955        38.6  ...   4.440005      1.347131            52.904538   5.043114
# 956        47.2  ...   0.230300      0.379684            51.393600   8.070066
# 961        44.2  ...   0.580665      0.773770            59.296625   5.594451
# 968        42.4  ...   0.847088      0.667127            54.127851   4.696595
# 970        46.1  ...   0.190916      0.080386            53.307300   5.656260
# 979        42.4  ...   0.448239      0.761295            49.823926   5.697446
# 981        37.4  ...  18.366967      4.488439            58.256171   5.344659
# 986        40.1  ...   1.405213      0.858126            60.095060   5.175689
# 992        42.9  ...   0.170068      0.688776            47.705106   1.886792
# 2203       31.1  ...   0.257326      0.081399            67.855619   9.866569
# 2315       40.0  ...  27.458769      0.870927            50.799618   6.347296
# 2335       36.3  ...   0.084975      2.811896            69.265133   6.445533
#
#                      county     state  state_short              county_state  \
# 127             Carson City    Nevada           NV            Carson City_NV
# 216              Montgomery  Virginia           VA             Montgomery_VA
# 225            Pittsylvania  Virginia           VA           Pittsylvania_VA
# 228           Prince George  Virginia           VA          Prince George_VA
# 229          Prince William  Virginia           VA         Prince William_VA
# 233                 Roanoke  Virginia           VA                Roanoke_VA
# 234              Rockbridge  Virginia           VA             Rockbridge_VA
# 235              Rockingham  Virginia           VA             Rockingham_VA
# 240             Southampton  Virginia           VA            Southampton_VA
# 241            Spotsylvania  Virginia           VA           Spotsylvania_VA
# 247              Washington  Virginia           VA             Washington_VA
# 249                    Wise  Virginia           VA                   Wise_VA
# 251                    York  Virginia           VA                   York_VA
# 253            Bristol city  Virginia           VA           Bristol city_VA
# 254        Buena Vista city  Virginia           VA       Buena Vista city_VA
# 255    Charlottesville city  Virginia           VA   Charlottesville city_VA
# 257   Colonial Heights city  Virginia           VA  Colonial Heights city_VA
# 258           Danville city  Virginia           VA          Danville city_VA
# 259       Falls Church city  Virginia           VA      Falls Church city_VA
# 260           Franklin city  Virginia           VA          Franklin city_VA
# 261     Fredericksburg city  Virginia           VA    Fredericksburg city_VA
# 263       Harrisonburg city  Virginia           VA      Harrisonburg city_VA
# 264           Hopewell city  Virginia           VA          Hopewell city_VA
# 265          Lynchburg city  Virginia           VA         Lynchburg city_VA
# 266           Manassas city  Virginia           VA          Manassas city_VA
# 269             Norton city  Virginia           VA            Norton city_VA
# 270         Petersburg city  Virginia           VA        Petersburg city_VA
# 271           Poquoson city  Virginia           VA          Poquoson city_VA
# 273            Radford city  Virginia           VA           Radford city_VA
# 276              Salem city  Virginia           VA             Salem city_VA
# 277           Staunton city  Virginia           VA          Staunton city_VA
# 280         Waynesboro city  Virginia           VA        Waynesboro city_VA
# 281       Williamsburg city  Virginia           VA      Williamsburg city_VA
# 282         Winchester city  Virginia           VA        Winchester city_VA
# 955               Albemarle  Virginia           VA              Albemarle_VA
# 956               Alleghany  Virginia           VA              Alleghany_VA
# 961                 Augusta  Virginia           VA                Augusta_VA
# 968                Campbell  Virginia           VA               Campbell_VA
# 970                 Carroll  Virginia           VA                Carroll_VA
# 979               Dinwiddie  Virginia           VA              Dinwiddie_VA
# 981                 Fairfax  Virginia           VA                Fairfax_VA
# 986               Frederick  Virginia           VA              Frederick_VA
# 992             Greensville  Virginia           VA            Greensville_VA
# 2203               LaGrange   Indiana           IN               LaGrange_IN
# 2315                   Maui    Hawaii           HI                   Maui_HI
# 2335                Fremont     Idaho           ID                Fremont_ID
#
#       industry_share_manufacturing  industry_share_mineoilgas
# 127                            NaN                        NaN
# 216                            NaN                        NaN
# 225                            NaN                        NaN
# 228                            NaN                        NaN
# 229                            NaN                        NaN
# 233                            NaN                        NaN
# 234                            NaN                        NaN
# 235                            NaN                        NaN
# 240                            NaN                        NaN
# 241                            NaN                        NaN
# 247                            NaN                        NaN
# 249                            NaN                        NaN
# 251                            NaN                        NaN
# 253                            NaN                        NaN
# 254                            NaN                        NaN
# 255                            NaN                        NaN
# 257                            NaN                        NaN
# 258                            NaN                        NaN
# 259                            NaN                        NaN
# 260                            NaN                        NaN
# 261                            NaN                        NaN
# 263                            NaN                        NaN
# 264                            NaN                        NaN
# 265                            NaN                        NaN
# 266                            NaN                        NaN
# 269                            NaN                        NaN
# 270                            NaN                        NaN
# 271                            NaN                        NaN
# 273                            NaN                        NaN
# 276                            NaN                        NaN
# 277                            NaN                        NaN
# 280                            NaN                        NaN
# 281                            NaN                        NaN
# 282                            NaN                        NaN
# 955                            NaN                        NaN
# 956                            NaN                        NaN
# 961                            NaN                        NaN
# 968                            NaN                        NaN
# 970                            NaN                        NaN
# 979                            NaN                        NaN
# 981                            NaN                        NaN
# 986                            NaN                        NaN
# 992                            NaN                        NaN
# 2203                           NaN                        NaN
# 2315                           NaN                        NaN
# 2335                           NaN                        NaN
#
# [46 rows x 40 columns]>

# %% [markdown]
# ### Fill missing values for industry share with mean share of respective state

# %%
data_main['industry_share_manufacturing'] = data_main['industry_share_manufacturing'].fillna(data_main.groupby('state')['industry_share_manufacturing'].transform('mean'))
data_main['industry_share_mineoilgas'] = data_main['industry_share_mineoilgas'].fillna(data_main.groupby('state')['industry_share_mineoilgas'].transform('mean'))
data_main.industry_share_manufacturing.value_counts(dropna = False)
# Out:
# 0.000000    295
# 0.142449     42
# 0.025427      1
# 0.152833      1
# 0.145394      1
#            ...
# 0.017131      1
# 0.025018      1
# 0.014692      1
# 0.004929      1
# 0.027242      1
# Name: industry_share_manufacturing, Length: 2712, dtype: int64

# %% [markdown]
# ### Join data_main with data_uv

# %%
data_main = pd.merge(data_main, data_uv, how='left', on='county_state')
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3053 entries, 0 to 3052
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avganncount                   3053 non-null   float64
#  1   avgdeathsperyear              3053 non-null   int64
#  2   target_deathrate              3053 non-null   float64
#  3   incidencerate                 3053 non-null   float64
#  4   medincome                     3053 non-null   int64
#  5   popest2015                    3053 non-null   int64
#  6   povertypercent                3053 non-null   float64
#  7   studypercap                   3053 non-null   float64
#  8   binnedinc                     3053 non-null   object
#  9   medianage                     3053 non-null   float64
#  10  medianagemale                 3053 non-null   float64
#  11  medianagefemale               3053 non-null   float64
#  12  geography                     3053 non-null   object
#  13  avghouseholdsize              3053 non-null   float64
#  14  percentmarried                3053 non-null   float64
#  15  pctnohs18_24                  3053 non-null   float64
#  16  pcths18_24                    3053 non-null   float64
#  17  pctsomecol18_24               763 non-null    float64
#  18  pctbachdeg18_24               3053 non-null   float64
#  19  pcths25_over                  3053 non-null   float64
#  20  pctbachdeg25_over             3053 non-null   float64
#  21  pctemployed16_over            2901 non-null   float64
#  22  pctunemployed16_over          3053 non-null   float64
#  23  pctprivatecoverage            3053 non-null   float64
#  24  pctprivatecoveragealone       2442 non-null   float64
#  25  pctempprivcoverage            3053 non-null   float64
#  26  pctpubliccoverage             3053 non-null   float64
#  27  pctpubliccoveragealone        3053 non-null   float64
#  28  pctwhite                      3053 non-null   float64
#  29  pctblack                      3053 non-null   float64
#  30  pctasian                      3053 non-null   float64
#  31  pctotherrace                  3053 non-null   float64
#  32  pctmarriedhouseholds          3053 non-null   float64
#  33  birthrate                     3053 non-null   float64
#  34  county                        3053 non-null   object
#  35  state                         3053 non-null   object
#  36  state_short                   3053 non-null   object
#  37  county_state                  3053 non-null   object
#  38  industry_share_manufacturing  3053 non-null   float64
#  39  industry_share_mineoilgas     3053 non-null   float64
#  40  uv                            2994 non-null   float64
# dtypes: float64(32), int64(3), object(6)
# memory usage: 1001.8+ KB

# %%
# check for missing values
data_main[(data_main['uv'].isna() == True)].count
# Out:
# <bound method DataFrame.count of       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 166         799.0               319             150.8          381.0
# 254         405.0               165             135.4          317.6
# 255          64.0                58             226.6          265.7
# 256          46.0                19             240.8          578.2
# 257         250.0                60             178.2          718.9
# 258         995.0               378             182.2          458.3
# 259         117.0                43             159.3          493.6
# 260         320.0               130             207.4          539.0
# 261          55.0                16             137.6          447.7
# 262          51.0                25             221.7          468.0
# 263         120.0                39             180.3          566.3
# 264         709.0               270             190.3          491.9
# 265         190.0                51             150.5          591.1
# 266         139.0                65             244.9          547.6
# 267         391.0               165             194.5          495.0
# 268         108.0                41             155.2          364.1
# 269         773.0               321             191.9          457.2
# 270         985.0               393             193.6          480.5
# 271          22.0                 9             197.3          461.0
# 272         249.0                88             224.4          651.3
# 273          67.0                24             159.2          441.3
# 274         489.0               229             218.1          473.2
# 275          51.0                21             193.1          463.1
# 276         948.0               406             200.2          475.4
# 277         576.0               235             201.2          512.4
# 278         162.0                63             186.6          511.5
# 279         181.0                64             176.1          537.9
# 280         406.0               169             199.3          472.0
# 281        1825.0               688             168.1          435.6
# 282         157.0                58             210.5          596.9
# 283         135.0                23             162.1         1014.2
# 284         117.0                59             192.8          401.9
# 822          81.0                37             209.6          464.8
# 897        3144.0              1419             226.0          497.2
# 1056        215.0                80             158.4          417.3
# 2069       1526.0               667             214.3          485.1
# 2318        911.0               343             147.6          402.7
# 2319       4646.0              1562             135.0          425.2
# 2320        326.0               130             149.4          392.2
# 2321        734.0               247             139.9          418.3
# 2719          8.0                 3             203.3          201.3
# 2720       1085.0               352             167.5          453.3
# 2721         37.0                20             218.8          338.2
# 2723         16.0                 7             216.6          409.2
# 2724        307.0               105             177.2          424.4
# 2725         13.0                 4             126.3          413.3
# 2726        119.0                41             166.3          390.1
# 2727        266.0                96             168.1          441.4
# 2728         63.0                25             205.0          477.3
# 2729         43.0                15             181.9          416.6
# 2730        357.0               127             184.3          469.3
# 2731         34.0                17             277.6          499.3
# 2732         26.0                12             256.9          501.1
# 2734         20.0                 9             199.3          373.5
# 2735         28.0                13             150.1          298.1
# 2736         27.0                11             184.3          372.9
# 2737         36.0                13             191.4          417.3
# 2738         27.0                11             206.6          475.1
# 2880        742.0               291             191.3          519.9
#
#       medincome  popest2015  povertypercent  studypercap           binnedinc  \
# 166       38974      214295            27.9   111.995147  (37413.8, 40362.7]
# 254       86419      153511             9.6    58.627720   (61494.5, 125635]
# 255       34099       17141            21.8   408.377574    [22640, 34218.1]
# 256       38331        6618            17.2     0.000000  (37413.8, 40362.7]
# 257       45890       46597            25.9   364.830354    (45201, 48021.6]
# 258       66625      235429             9.8    46.723216   (61494.5, 125635]
# 259       52355       17820            11.5     0.000000  (51046.4, 54545.6]
# 260       33646       42082            23.6   356.446937    [22640, 34218.1]
# 261      125635       13892             3.2     0.000000   (61494.5, 125635]
# 262       38583        8490            22.5     0.000000  (37413.8, 40362.7]
# 263       51195       28118            16.8  1280.318657  (51046.4, 54545.6]
# 264       47615      136454            15.2   168.554971    (45201, 48021.6]
# 265       38541       52538            28.3    57.101527  (37413.8, 40362.7]
# 266       40122       22378            19.5     0.000000  (37413.8, 40362.7]
# 267       40065       79812            25.0   388.412770  (37413.8, 40362.7]
# 268       72510       41764             9.8     0.000000   (61494.5, 125635]
# 269       48440      182385            16.7   159.004304  (48021.6, 51046.4]
# 270       42567      246393            23.4   523.553835  (40362.7, 42724.4]
# 271       31620        3939            21.6  3046.458492    [22640, 34218.1]
# 272       32749       32477            25.8     0.000000    [22640, 34218.1]
# 273       84213       12059             5.9     0.000000   (61494.5, 125635]
# 274       43045       96201            18.3   187.108242    (42724.4, 45201]
# 275       34267       17403            32.4     0.000000  (34218.1, 37413.8]
# 276       42074      220289            25.0   122.566265  (40362.7, 42724.4]
# 277       40735       99897            20.4   430.443357  (40362.7, 42724.4]
# 278       54195       25432            10.2   432.525952  (51046.4, 54545.6]
# 279       42552       24416            16.5     0.000000  (40362.7, 42724.4]
# 280       60735       88161            13.6    11.342884  (54545.6, 61494.5]
# 281       67676      452745             8.6    88.349954   (61494.5, 125635]
# 282       44843       21491            14.6     0.000000    (42724.4, 45201]
# 283       46954       15052            20.1     0.000000    (45201, 48021.6]
# 284       44537       27284            13.4  1026.242486    (42724.4, 45201]
# 822       44139       14974            18.0     0.000000    (42724.4, 45201]
# 897       41895      621849            23.3   886.067196  (40362.7, 42724.4]
# 1056      85885       65065             4.0    46.107738   (61494.5, 125635]
# 2069      35681      315685            28.8  2369.450560  (34218.1, 37413.8]
# 2318      51887      196428            18.1     0.000000  (51046.4, 54545.6]
# 2319      73985      998714             9.8   708.911660   (61494.5, 125635]
# 2320      58883       71735            12.3   655.189238  (54545.6, 61494.5]
# 2321      64916      164637            13.1   103.257469   (61494.5, 125635]
# 2719      68387        5702             9.9     0.000000   (61494.5, 125635]
# 2720      75200      298695            10.0   565.794540   (61494.5, 125635]
# 2721      45808       17946            23.8     0.000000    (45201, 48021.6]
# 2723      51082        4997            17.5     0.000000  (51046.4, 54545.6]
# 2724      67801       99631             9.5   270.999990   (61494.5, 125635]
# 2725      67260        2534             9.8     0.000000   (61494.5, 125635]
# 2726      80835       32756             7.9     0.000000   (61494.5, 125635]
# 2727      62532       58059            11.5     0.000000   (61494.5, 125635]
# 2728      57776       13709            12.4     0.000000  (54545.6, 61494.5]
# 2729      67972       13889             8.3     0.000000   (61494.5, 125635]
# 2730      73981      101095            10.7     0.000000   (61494.5, 125635]
# 2731      47160        9846            26.1     0.000000    (45201, 48021.6]
# 2732      75682        9687            11.5   103.231134   (61494.5, 125635]
# 2734      65192        7752            23.2     0.000000   (61494.5, 125635]
# 2735      65765        8863             8.6     0.000000   (61494.5, 125635]
# 2736      59641        6839            13.8     0.000000  (54545.6, 61494.5]
# 2737      73998        9362             9.9     0.000000   (61494.5, 125635]
# 2738      36708        5533            25.7     0.000000  (34218.1, 37413.8]
# 2880      51205      111333            13.6  2065.874449  (51046.4, 54545.6]
#
#       medianage  ...  pctotherrace  pctmarriedhouseholds  birthrate  \
# 166        32.4  ...      4.908793             48.156818   5.880466
# 254        36.0  ...      3.159763             36.216152   6.214828
# 255        41.8  ...      1.289660             40.541591   3.868375
# 256        33.8  ...      0.000000             45.926197  11.887694
# 257        29.8  ...      0.310531             30.492339   2.753791
# 258        36.5  ...      1.329136             54.731470   5.746827
# 259        40.0  ...      1.741365             42.696313   3.664122
# 260        41.8  ...      1.703180             33.347702   3.236584
# 261        37.7  ...      3.554253             53.271390   3.066181
# 262        38.0  ...      0.744945             30.842745   4.927099
# 263        29.4  ...      3.668553             34.216270   4.269052
# 264        35.4  ...      1.149685             39.695882   4.729382
# 265        23.5  ...      1.181210             34.669998   2.564793
# 266        36.9  ...      4.241663             30.507696   5.969290
# 267        28.7  ...      0.749763             37.783932   5.960878
# 268        33.3  ...      4.440027             56.913054   6.934168
# 269        32.8  ...      1.579502             38.428909   5.236699
# 270        30.0  ...      2.179652             34.307542   6.373341
# 271        39.3  ...      1.472423             32.641615   3.938224
# 272        39.5  ...      1.273231             27.009295   4.372409
# 273        43.8  ...      0.389169             62.602327   4.361371
# 274        34.9  ...      1.274250             35.938733   5.954956
# 275        22.3  ...      0.732837             31.130181   1.039130
# 276        32.9  ...      1.136922             23.885628   4.888983
# 277        38.0  ...      1.500972             33.559033   6.673086
# 278        40.5  ...      0.596066             46.251867   4.609250
# 279        42.3  ...      0.632414             40.521806   3.909799
# 280        38.3  ...      0.548826             52.220071   5.719706
# 281        35.0  ...      1.417163             50.409042   5.841796
# 282        38.5  ...      2.245863             40.803898   7.446378
# 283        24.6  ...      0.460892             36.337594   2.181467
# 284        37.0  ...      2.723793             38.678356   6.642836
# 822        38.6  ...      0.154373             53.684021   5.144490
# 897        34.6  ...      1.670324             24.024634   5.449538
# 1056       37.5  ...      2.136773             57.201139   5.099793
# 2069       34.6  ...      0.820827             24.429078   4.685605
# 2318       41.1  ...      2.082702             47.978416   6.030934
# 2319       36.9  ...      0.915383             52.713161   6.457474
# 2320       41.6  ...      0.665796             54.706539   4.798814
# 2321       40.0  ...      0.870927             50.799618   6.347296
# 2719       36.8  ...      5.295567             42.882250   4.391052
# 2720       32.5  ...      1.747201             48.361303   5.994294
# 2721       26.7  ...      0.343159             45.521390   9.156280
# 2723       29.7  ...      0.482025             46.478873  11.801242
# 2724       30.4  ...      0.891630             50.354112   7.382578
# 2725       45.5  ...      0.507812             47.789116   5.374280
# 2726       37.0  ...      1.186561             49.380882   5.601633
# 2727       40.5  ...      0.559235             51.021643   5.680094
# 2728       38.7  ...      0.656982             46.667932   4.936668
# 2729       32.4  ...      2.798254             55.429321   6.768559
# 2730       34.6  ...      0.712221             57.492443   4.854021
# 2731       27.8  ...      0.142074             38.324786  11.350381
# 2732       33.9  ...      1.851660             38.073394  10.633353
# 2734       26.1  ...      0.581997             44.929059  12.392918
# 2735       38.9  ...      1.028738             48.041475   3.141875
# 2736       35.8  ...      1.209276             56.447803   7.237300
# 2737       36.6  ...      1.195799             52.059801   5.470675
# 2738       35.0  ...      0.212615             36.377397   6.744604
# 2880       41.6  ...      1.118326             49.737806   4.843426
#
#                                county       state  state_short  \
# 166                          Doña Ana  New Mexico           NM
# 254                   Alexandria city    Virginia           VA
# 255                      Bristol city    Virginia           VA
# 256                  Buena Vista city    Virginia           VA
# 257              Charlottesville city    Virginia           VA
# 258                   Chesapeake city    Virginia           VA
# 259             Colonial Heights city    Virginia           VA
# 260                     Danville city    Virginia           VA
# 261                 Falls Church city    Virginia           VA
# 262                     Franklin city    Virginia           VA
# 263               Fredericksburg city    Virginia           VA
# 264                      Hampton city    Virginia           VA
# 265                 Harrisonburg city    Virginia           VA
# 266                     Hopewell city    Virginia           VA
# 267                    Lynchburg city    Virginia           VA
# 268                     Manassas city    Virginia           VA
# 269                 Newport News city    Virginia           VA
# 270                      Norfolk city    Virginia           VA
# 271                       Norton city    Virginia           VA
# 272                   Petersburg city    Virginia           VA
# 273                     Poquoson city    Virginia           VA
# 274                   Portsmouth city    Virginia           VA
# 275                      Radford city    Virginia           VA
# 276                     Richmond city    Virginia           VA
# 277                      Roanoke city    Virginia           VA
# 278                        Salem city    Virginia           VA
# 279                     Staunton city    Virginia           VA
# 280                      Suffolk city    Virginia           VA
# 281               Virginia Beach city    Virginia           VA
# 282                   Waynesboro city    Virginia           VA
# 283                 Williamsburg city    Virginia           VA
# 284                   Winchester city    Virginia           VA
# 822                           LaSalle   Louisiana           LA
# 897                    Baltimore city    Maryland           MD
# 1056                       Broomfield    Colorado           CO
# 2069                   St. Louis city    Missouri           MO
# 2318                           Hawaii      Hawaii           HI
# 2319                         Honolulu      Hawaii           HI
# 2320                            Kauai      Hawaii           HI
# 2321                             Maui      Hawaii           HI
# 2719       Aleutians West Census Area      Alaska           AK
# 2720           Anchorage Municipality      Alaska           AK
# 2721               Bethel Census Area      Alaska           AK
# 2723           Dillingham Census Area      Alaska           AK
# 2724     Fairbanks North Star Borough      Alaska           AK
# 2725                   Haines Borough      Alaska           AK
# 2726          Juneau City and Borough      Alaska           AK
# 2727          Kenai Peninsula Borough      Alaska           AK
# 2728        Ketchikan Gateway Borough      Alaska           AK
# 2729            Kodiak Island Borough      Alaska           AK
# 2730        Matanuska-Susitna Borough      Alaska           AK
# 2731                 Nome Census Area      Alaska           AK
# 2732              North Slope Borough      Alaska           AK
# 2734         Northwest Arctic Borough      Alaska           AK
# 2735           Sitka City and Borough      Alaska           AK
# 2736  Southeast Fairbanks Census Area      Alaska           AK
# 2737       Valdez-Cordova Census Area      Alaska           AK
# 2738        Yukon-Koyukuk Census Area      Alaska           AK
# 2880                          LaSalle    Illinois           IL
#
#                             county_state  industry_share_manufacturing  \
# 166                          Doña Ana_NM                      0.035677
# 254                   Alexandria city_VA                      0.000000
# 255                      Bristol city_VA                      0.142449
# 256                  Buena Vista city_VA                      0.142449
# 257              Charlottesville city_VA                      0.142449
# 258                   Chesapeake city_VA                      0.059441
# 259             Colonial Heights city_VA                      0.142449
# 260                     Danville city_VA                      0.142449
# 261                 Falls Church city_VA                      0.142449
# 262                     Franklin city_VA                      0.142449
# 263               Fredericksburg city_VA                      0.142449
# 264                      Hampton city_VA                      0.049930
# 265                 Harrisonburg city_VA                      0.142449
# 266                     Hopewell city_VA                      0.142449
# 267                    Lynchburg city_VA                      0.142449
# 268                     Manassas city_VA                      0.142449
# 269                 Newport News city_VA                      0.299573
# 270                      Norfolk city_VA                      0.036559
# 271                       Norton city_VA                      0.142449
# 272                   Petersburg city_VA                      0.142449
# 273                     Poquoson city_VA                      0.142449
# 274                   Portsmouth city_VA                      0.000000
# 275                      Radford city_VA                      0.142449
# 276                     Richmond city_VA                      0.089145
# 277                      Roanoke city_VA                      0.000000
# 278                        Salem city_VA                      0.142449
# 279                     Staunton city_VA                      0.142449
# 280                      Suffolk city_VA                      0.378381
# 281               Virginia Beach city_VA                      0.040351
# 282                   Waynesboro city_VA                      0.142449
# 283                 Williamsburg city_VA                      0.142449
# 284                   Winchester city_VA                      0.142449
# 822                           LaSalle_LA                      0.063162
# 897                    Baltimore city_MD                      0.046095
# 1056                       Broomfield_CO                      0.272525
# 2069                   St. Louis city_MO                      0.152833
# 2318                           Hawaii_HI                      0.000000
# 2319                         Honolulu_HI                      0.025372
# 2320                            Kauai_HI                      0.000000
# 2321                             Maui_HI                      0.008457
# 2719       Aleutians West Census Area_AK                      0.419544
# 2720           Anchorage Municipality_AK                      0.010041
# 2721               Bethel Census Area_AK                      0.000000
# 2723           Dillingham Census Area_AK                      0.234877
# 2724     Fairbanks North Star Borough_AK                      0.037174
# 2725                   Haines Borough_AK                      0.089957
# 2726          Juneau City and Borough_AK                      0.012841
# 2727          Kenai Peninsula Borough_AK                      0.171904
# 2728        Ketchikan Gateway Borough_AK                      0.046558
# 2729            Kodiak Island Borough_AK                      0.159038
# 2730        Matanuska-Susitna Borough_AK                      0.013938
# 2731                 Nome Census Area_AK                      0.000000
# 2732              North Slope Borough_AK                      0.000000
# 2734         Northwest Arctic Borough_AK                      0.001389
# 2735           Sitka City and Borough_AK                      0.089607
# 2736  Southeast Fairbanks Census Area_AK                      0.004986
# 2737       Valdez-Cordova Census Area_AK                      0.038605
# 2738        Yukon-Koyukuk Census Area_AK                      0.000000
# 2880                          LaSalle_IL                      0.162297
#
#       industry_share_mineoilgas  uv
# 166                    0.001135 NaN
# 254                    0.000000 NaN
# 255                    0.016149 NaN
# 256                    0.016149 NaN
# 257                    0.016149 NaN
# 258                    0.001335 NaN
# 259                    0.016149 NaN
# 260                    0.016149 NaN
# 261                    0.016149 NaN
# 262                    0.016149 NaN
# 263                    0.016149 NaN
# 264                    0.000000 NaN
# 265                    0.016149 NaN
# 266                    0.016149 NaN
# 267                    0.016149 NaN
# 268                    0.016149 NaN
# 269                    0.000074 NaN
# 270                    0.000035 NaN
# 271                    0.016149 NaN
# 272                    0.016149 NaN
# 273                    0.016149 NaN
# 274                    0.000000 NaN
# 275                    0.016149 NaN
# 276                    0.000390 NaN
# 277                    0.002729 NaN
# 278                    0.016149 NaN
# 279                    0.016149 NaN
# 280                    0.000413 NaN
# 281                    0.000000 NaN
# 282                    0.016149 NaN
# 283                    0.016149 NaN
# 284                    0.016149 NaN
# 822                    0.273125 NaN
# 897                    0.000013 NaN
# 1056                   0.002083 NaN
# 2069                   0.000000 NaN
# 2318                   0.000049 NaN
# 2319                   0.001251 NaN
# 2320                   0.001090 NaN
# 2321                   0.000797 NaN
# 2719                   0.023742 NaN
# 2720                   0.030959 NaN
# 2721                   0.051264 NaN
# 2723                   0.000652 NaN
# 2724                   0.068661 NaN
# 2725                   0.031283 NaN
# 2726                   0.209865 NaN
# 2727                   0.072801 NaN
# 2728                   0.000001 NaN
# 2729                   0.001729 NaN
# 2730                   0.009251 NaN
# 2731                   0.031128 NaN
# 2732                   0.890749 NaN
# 2734                   0.729937 NaN
# 2735                   0.000000 NaN
# 2736                   0.588392 NaN
# 2737                   0.002409 NaN
# 2738                   0.017590 NaN
# 2880                   0.048274 NaN
#
# [59 rows x 41 columns]>

# %% [markdown]
# ### Fill missing values for UV with mean share of respective state

# %%
data_main['uv'] = data_main['uv'].fillna(data_main.groupby('state')['uv'].transform('mean'))
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3053 entries, 0 to 3052
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avganncount                   3053 non-null   float64
#  1   avgdeathsperyear              3053 non-null   int64
#  2   target_deathrate              3053 non-null   float64
#  3   incidencerate                 3053 non-null   float64
#  4   medincome                     3053 non-null   int64
#  5   popest2015                    3053 non-null   int64
#  6   povertypercent                3053 non-null   float64
#  7   studypercap                   3053 non-null   float64
#  8   binnedinc                     3053 non-null   object
#  9   medianage                     3053 non-null   float64
#  10  medianagemale                 3053 non-null   float64
#  11  medianagefemale               3053 non-null   float64
#  12  geography                     3053 non-null   object
#  13  avghouseholdsize              3053 non-null   float64
#  14  percentmarried                3053 non-null   float64
#  15  pctnohs18_24                  3053 non-null   float64
#  16  pcths18_24                    3053 non-null   float64
#  17  pctsomecol18_24               763 non-null    float64
#  18  pctbachdeg18_24               3053 non-null   float64
#  19  pcths25_over                  3053 non-null   float64
#  20  pctbachdeg25_over             3053 non-null   float64
#  21  pctemployed16_over            2901 non-null   float64
#  22  pctunemployed16_over          3053 non-null   float64
#  23  pctprivatecoverage            3053 non-null   float64
#  24  pctprivatecoveragealone       2442 non-null   float64
#  25  pctempprivcoverage            3053 non-null   float64
#  26  pctpubliccoverage             3053 non-null   float64
#  27  pctpubliccoveragealone        3053 non-null   float64
#  28  pctwhite                      3053 non-null   float64
#  29  pctblack                      3053 non-null   float64
#  30  pctasian                      3053 non-null   float64
#  31  pctotherrace                  3053 non-null   float64
#  32  pctmarriedhouseholds          3053 non-null   float64
#  33  birthrate                     3053 non-null   float64
#  34  county                        3053 non-null   object
#  35  state                         3053 non-null   object
#  36  state_short                   3053 non-null   object
#  37  county_state                  3053 non-null   object
#  38  industry_share_manufacturing  3053 non-null   float64
#  39  industry_share_mineoilgas     3053 non-null   float64
#  40  uv                            3031 non-null   float64
# dtypes: float64(32), int64(3), object(6)
# memory usage: 1001.8+ KB

# %%
# check for missing values
data_main[(data_main['uv'].isna() == True)].head()
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 2318        911.0               343             147.6          402.7
# 2319       4646.0              1562             135.0          425.2
# 2320        326.0               130             149.4          392.2
# 2321        734.0               247             139.9          418.3
# 2719          8.0                 3             203.3          201.3
#
#       medincome  popest2015  povertypercent  studypercap           binnedinc  \
# 2318      51887      196428            18.1     0.000000  (51046.4, 54545.6]
# 2319      73985      998714             9.8   708.911660   (61494.5, 125635]
# 2320      58883       71735            12.3   655.189238  (54545.6, 61494.5]
# 2321      64916      164637            13.1   103.257469   (61494.5, 125635]
# 2719      68387        5702             9.9     0.000000   (61494.5, 125635]
#
#       medianage  ...  pctotherrace  pctmarriedhouseholds birthrate  \
# 2318       41.1  ...      2.082702             47.978416  6.030934
# 2319       36.9  ...      0.915383             52.713161  6.457474
# 2320       41.6  ...      0.665796             54.706539  4.798814
# 2321       40.0  ...      0.870927             50.799618  6.347296
# 2719       36.8  ...      5.295567             42.882250  4.391052
#
#                           county   state  state_short  \
# 2318                      Hawaii  Hawaii           HI
# 2319                    Honolulu  Hawaii           HI
# 2320                       Kauai  Hawaii           HI
# 2321                        Maui  Hawaii           HI
# 2719  Aleutians West Census Area  Alaska           AK
#
#                        county_state  industry_share_manufacturing  \
# 2318                      Hawaii_HI                      0.000000
# 2319                    Honolulu_HI                      0.025372
# 2320                       Kauai_HI                      0.000000
# 2321                        Maui_HI                      0.008457
# 2719  Aleutians West Census Area_AK                      0.419544
#
#       industry_share_mineoilgas  uv
# 2318                   0.000049 NaN
# 2319                   0.001251 NaN
# 2320                   0.001090 NaN
# 2321                   0.000797 NaN
# 2719                   0.023742 NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# It seems like Alaska and Hawaii are missing in the UV table. I'll later decide if I kick both states from the dataset or kick the UV numbers instead.

# %% [markdown]
# ### Join data_main with data_county_class

# %%
data_main = pd.merge(data_main, data_county_class, how='left', on='county_state')

# %% [markdown]
# ## 2.3 Data transforming

# %% [markdown]
# ### Check data types

# %%
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3053 entries, 0 to 3052
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avganncount                   3053 non-null   float64
#  1   avgdeathsperyear              3053 non-null   int64
#  2   target_deathrate              3053 non-null   float64
#  3   incidencerate                 3053 non-null   float64
#  4   medincome                     3053 non-null   int64
#  5   popest2015                    3053 non-null   int64
#  6   povertypercent                3053 non-null   float64
#  7   studypercap                   3053 non-null   float64
#  8   binnedinc                     3053 non-null   object
#  9   medianage                     3053 non-null   float64
#  10  medianagemale                 3053 non-null   float64
#  11  medianagefemale               3053 non-null   float64
#  12  geography                     3053 non-null   object
#  13  avghouseholdsize              3053 non-null   float64
#  14  percentmarried                3053 non-null   float64
#  15  pctnohs18_24                  3053 non-null   float64
#  16  pcths18_24                    3053 non-null   float64
#  17  pctsomecol18_24               763 non-null    float64
#  18  pctbachdeg18_24               3053 non-null   float64
#  19  pcths25_over                  3053 non-null   float64
#  20  pctbachdeg25_over             3053 non-null   float64
#  21  pctemployed16_over            2901 non-null   float64
#  22  pctunemployed16_over          3053 non-null   float64
#  23  pctprivatecoverage            3053 non-null   float64
#  24  pctprivatecoveragealone       2442 non-null   float64
#  25  pctempprivcoverage            3053 non-null   float64
#  26  pctpubliccoverage             3053 non-null   float64
#  27  pctpubliccoveragealone        3053 non-null   float64
#  28  pctwhite                      3053 non-null   float64
#  29  pctblack                      3053 non-null   float64
#  30  pctasian                      3053 non-null   float64
#  31  pctotherrace                  3053 non-null   float64
#  32  pctmarriedhouseholds          3053 non-null   float64
#  33  birthrate                     3053 non-null   float64
#  34  county                        3053 non-null   object
#  35  state                         3053 non-null   object
#  36  state_short                   3053 non-null   object
#  37  county_state                  3053 non-null   object
#  38  industry_share_manufacturing  3053 non-null   float64
#  39  industry_share_mineoilgas     3053 non-null   float64
#  40  uv                            3031 non-null   float64
#  41  poppct_urban                  3053 non-null   float64
#  42  poppct_rural                  3053 non-null   float64
# dtypes: float64(34), int64(3), object(6)
# memory usage: 1.0+ MB

# %%
data_main.describe()
# Out:
#         avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count   3053.000000       3053.000000       3053.000000    3053.000000
# mean     610.126938        187.363249        178.626728     448.245228
# std     1421.266302        505.932866         27.746053      54.535801
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         62.000000        178.100000     453.549422
# 75%      519.000000        149.000000        195.200000     480.800000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medincome    popest2015  povertypercent  studypercap    medianage  \
# count    3053.000000  3.053000e+03     3053.000000  3053.000000  3053.000000
# mean    47098.507697  1.034629e+05       16.868031   155.342205    45.264887
# std     12094.325334  3.299452e+05        6.410199   529.143026    45.260401
# min     22640.000000  8.270000e+02        3.200000     0.000000    22.300000
# 25%     38887.000000  1.170300e+04       12.100000     0.000000    37.700000
# 50%     45219.000000  2.677700e+04       15.900000     0.000000    41.000000
# 75%     52513.000000  6.887900e+04       20.400000    83.840677    44.000000
# max    125635.000000  1.017029e+07       47.400000  9762.308998   624.000000
#
#        medianagemale  ...     pctblack     pctasian  pctotherrace  \
# count    3053.000000  ...  3053.000000  3053.000000   3053.000000
# mean       39.571471  ...     9.123786     1.262336      1.982211
# std         5.222515  ...    14.530692     2.627900      3.514961
# min        22.400000  ...     0.000000     0.000000      0.000000
# 25%        36.400000  ...     0.621371     0.254714      0.295421
# 50%        39.600000  ...     2.274510     0.550796      0.826185
# 75%        42.500000  ...    10.530371     1.223758      2.176268
# max        64.700000  ...    85.947799    42.619425     41.930251
#
#        pctmarriedhouseholds    birthrate  industry_share_manufacturing  \
# count           3053.000000  3053.000000                   3053.000000
# mean              51.245417     5.640925                      0.142743
# std                6.569959     1.984728                      0.132637
# min               22.992490     0.000000                      0.000000
# 25%               47.756410     4.523580                      0.038605
# 50%               51.669941     5.381478                      0.110233
# 75%               55.396115     6.491885                      0.210747
# max               78.075397    21.326165                      0.894266
#
#        industry_share_mineoilgas           uv  poppct_urban  poppct_rural
# count                3053.000000  3031.000000   3053.000000   3053.000000
# mean                    0.046957  4297.953606     41.928238     58.071765
# std                     0.129821   419.057080     31.207262     31.207260
# min                     0.000000  3012.000000      0.000000      0.000000
# 25%                     0.000261  3959.000000     15.160000     32.930000
# 50%                     0.002693  4270.000000     41.090000     58.910000
# 75%                     0.018307  4571.000000     67.070000     84.840000
# max                     0.978804  5723.000000    100.000000    100.000000
#
# [8 rows x 37 columns]

# %%
# Harmonize percentages
data_main.industry_share_manufacturing = data_main.industry_share_manufacturing * 100
data_main.industry_share_mineoilgas = data_main.industry_share_mineoilgas * 100

# %% [markdown]
# ### Check for missing values

# %%
data_main.isna().sum()
# Out:
# avganncount                        0
# avgdeathsperyear                   0
# target_deathrate                   0
# incidencerate                      0
# medincome                          0
# popest2015                         0
# povertypercent                     0
# studypercap                        0
# binnedinc                          0
# medianage                          0
# medianagemale                      0
# medianagefemale                    0
# geography                          0
# avghouseholdsize                   0
# percentmarried                     0
# pctnohs18_24                       0
# pcths18_24                         0
# pctsomecol18_24                 2290
# pctbachdeg18_24                    0
# pcths25_over                       0
# pctbachdeg25_over                  0
# pctemployed16_over               152
# pctunemployed16_over               0
# pctprivatecoverage                 0
# pctprivatecoveragealone          611
# pctempprivcoverage                 0
# pctpubliccoverage                  0
# pctpubliccoveragealone             0
# pctwhite                           0
# pctblack                           0
# pctasian                           0
# pctotherrace                       0
# pctmarriedhouseholds               0
# birthrate                          0
# county                             0
# state                              0
# state_short                        0
# county_state                       0
# industry_share_manufacturing       0
# industry_share_mineoilgas          0
# uv                                22
# poppct_urban                       0
# poppct_rural                       0
# dtype: int64

# %% [markdown]
# ### Fill missing values for the column pctsomecol 18-24

# %%
#data_main.to_csv('export for tableau.csv')
data_main['pctsomecol18_24'] = data_main['pctsomecol18_24'].fillna(100 - data_main['pctnohs18_24'] - data_main['pcths18_24'] - data_main['pctbachdeg18_24'])

# %% [markdown]
# ### Filling missing values for pctemployed16_over

# %%
# Create a statewide ratio between employed and unemployed
data_main['ratioemployment'] = data_main.groupby('state')['pctemployed16_over'].transform('mean')/data_main.groupby('state')['pctunemployed16_over'].transform('mean')
data_main['ratioemployment']
# Out:
# 0        5.829581
# 1        5.829581
# 2        5.829581
# 3        5.829581
# 4        5.829581
#           ...
# 3048    13.217273
# 3049    13.217273
# 3050    13.217273
# 3051    13.217273
# 3052    13.217273
# Name: ratioemployment, Length: 3053, dtype: float64

# %%
# Fill the missing values with the product of pctunemployed & ratioemployment
data_main['pctemployed16_over'] = data_main['pctemployed16_over'].fillna(data_main['pctunemployed16_over'] * data_main['ratioemployment'])

# %%
data_main[['pctemployed16_over','pctunemployed16_over']].head(20)
# Out:
#     pctemployed16_over  pctunemployed16_over
# 0            51.900000                   8.0
# 1            55.900000                   7.8
# 2            45.900000                   7.0
# 3            48.300000                  12.1
# 4            48.200000                   4.8
# 5            44.100000                  12.9
# 6            51.800000                   8.9
# 7            40.900000                   8.9
# 8            39.500000                  10.3
# 9            56.600000                   9.2
# 10           54.600000                   5.9
# 11           47.802563                   8.2
# 12           51.500000                   8.3
# 13           62.100000                   7.5
# 14           55.100000                   8.4
# 15           46.300000                   9.4
# 16           56.500000                   8.5
# 17           35.700000                  10.6
# 18           54.500000                   6.4
# 19           57.800000                   8.2

# %% [markdown]
# ### Fill missing values for pctprivatecoveragealone

# %%
# Draw a scatterplott
sns.regplot(x=data_main["pctprivatecoveragealone"], y=data_main["pctempprivcoverage"])
# Out:
# <AxesSubplot:xlabel='pctprivatecoveragealone', ylabel='pctempprivcoverage'>

# %% [markdown]
# There seems to be a correlation between pctprivatecoveragealone and pctempprivatecoverage exept for some outliers

# %%
# Create a statewide ratio between both variables
data_main['ratiocoverage'] = data_main.groupby('state')['pctprivatecoveragealone'].transform('mean')/data_main.groupby('state')['pctempprivcoverage'].transform('mean')
data_main['ratiocoverage']
# Out:
# 0       1.208875
# 1       1.208875
# 2       1.208875
# 3       1.208875
# 4       1.208875
#           ...
# 3048    1.226752
# 3049    1.226752
# 3050    1.226752
# 3051    1.226752
# 3052    1.226752
# Name: ratiocoverage, Length: 3053, dtype: float64

# %%
# Fill the missing values with the product of pctempprivcoverage & ratiocoverage
data_main['pctprivatecoveragealone'] = data_main['pctprivatecoveragealone'].fillna(data_main['pctempprivcoverage'] * data_main['ratiocoverage'])

# %%
data_main[['pctprivatecoveragealone','pctempprivcoverage']].head(20)
# Out:
#     pctprivatecoveragealone  pctempprivcoverage
# 0                 50.289207                41.6
# 1                 53.800000                43.6
# 2                 43.500000                34.9
# 3                 40.300000                35.0
# 4                 43.900000                35.1
# 5                 38.800000                32.6
# 6                 35.000000                28.3
# 7                 33.100000                25.9
# 8                 37.800000                29.9
# 9                 53.674058                44.4
# 10                33.727617                27.9
# 11                45.937257                38.0
# 12                49.700000                42.6
# 13                61.600000                54.3
# 14                50.600000                42.5
# 15                39.300000                33.9
# 16                55.400000                43.5
# 17                38.600000                35.2
# 18                47.600000                40.0
# 19                54.600000                44.8

# %%
data_main.to_csv('export_to_tableau.csv')

# %% [markdown]
# ### Binning of the data using qcut

# %%
data_main.describe()
# Out:
#         avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count   3053.000000       3053.000000       3053.000000    3053.000000
# mean     610.126938        187.363249        178.626728     448.245228
# std     1421.266302        505.932866         27.746053      54.535801
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         62.000000        178.100000     453.549422
# 75%      519.000000        149.000000        195.200000     480.800000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medincome    popest2015  povertypercent  studypercap    medianage  \
# count    3053.000000  3.053000e+03     3053.000000  3053.000000  3053.000000
# mean    47098.507697  1.034629e+05       16.868031   155.342205    45.264887
# std     12094.325334  3.299452e+05        6.410199   529.143026    45.260401
# min     22640.000000  8.270000e+02        3.200000     0.000000    22.300000
# 25%     38887.000000  1.170300e+04       12.100000     0.000000    37.700000
# 50%     45219.000000  2.677700e+04       15.900000     0.000000    41.000000
# 75%     52513.000000  6.887900e+04       20.400000    83.840677    44.000000
# max    125635.000000  1.017029e+07       47.400000  9762.308998   624.000000
#
#        medianagemale  ...  pctotherrace  pctmarriedhouseholds    birthrate  \
# count    3053.000000  ...   3053.000000           3053.000000  3053.000000
# mean       39.571471  ...      1.982211             51.245417     5.640925
# std         5.222515  ...      3.514961              6.569959     1.984728
# min        22.400000  ...      0.000000             22.992490     0.000000
# 25%        36.400000  ...      0.295421             47.756410     4.523580
# 50%        39.600000  ...      0.826185             51.669941     5.381478
# 75%        42.500000  ...      2.176268             55.396115     6.491885
# max        64.700000  ...     41.930251             78.075397    21.326165
#
#        industry_share_manufacturing  industry_share_mineoilgas           uv  \
# count                   3053.000000                3053.000000  3031.000000
# mean                      14.274287                   4.695685  4297.953606
# std                       13.263709                  12.982104   419.057080
# min                        0.000000                   0.000000  3012.000000
# 25%                        3.860509                   0.026069  3959.000000
# 50%                       11.023347                   0.269338  4270.000000
# 75%                       21.074741                   1.830721  4571.000000
# max                       89.426572                  97.880371  5723.000000
#
#        poppct_urban  poppct_rural  ratioemployment  ratiocoverage
# count   3053.000000   3053.000000      3053.000000    3053.000000
# mean      41.928238     58.071765         7.827693       1.178618
# std       31.207262     31.207260         3.677470       0.058723
# min        0.000000      0.000000         3.791086       1.056429
# 25%       15.160000     32.930000         5.207784       1.140009
# 50%       41.090000     58.910000         7.025973       1.172764
# 75%       67.070000     84.840000         8.432822       1.196714
# max      100.000000    100.000000        22.803272       1.324858
#
# [8 rows x 39 columns]

# %%
# Move numericals to dedicated dataframe
dfnum = data_main.select_dtypes('number')
dfnum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3053 entries, 0 to 3052
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avganncount                   3053 non-null   float64
#  1   avgdeathsperyear              3053 non-null   int64
#  2   target_deathrate              3053 non-null   float64
#  3   incidencerate                 3053 non-null   float64
#  4   medincome                     3053 non-null   int64
#  5   popest2015                    3053 non-null   int64
#  6   povertypercent                3053 non-null   float64
#  7   studypercap                   3053 non-null   float64
#  8   medianage                     3053 non-null   float64
#  9   medianagemale                 3053 non-null   float64
#  10  medianagefemale               3053 non-null   float64
#  11  avghouseholdsize              3053 non-null   float64
#  12  percentmarried                3053 non-null   float64
#  13  pctnohs18_24                  3053 non-null   float64
#  14  pcths18_24                    3053 non-null   float64
#  15  pctsomecol18_24               3053 non-null   float64
#  16  pctbachdeg18_24               3053 non-null   float64
#  17  pcths25_over                  3053 non-null   float64
#  18  pctbachdeg25_over             3053 non-null   float64
#  19  pctemployed16_over            3053 non-null   float64
#  20  pctunemployed16_over          3053 non-null   float64
#  21  pctprivatecoverage            3053 non-null   float64
#  22  pctprivatecoveragealone       3053 non-null   float64
#  23  pctempprivcoverage            3053 non-null   float64
#  24  pctpubliccoverage             3053 non-null   float64
#  25  pctpubliccoveragealone        3053 non-null   float64
#  26  pctwhite                      3053 non-null   float64
#  27  pctblack                      3053 non-null   float64
#  28  pctasian                      3053 non-null   float64
#  29  pctotherrace                  3053 non-null   float64
#  30  pctmarriedhouseholds          3053 non-null   float64
#  31  birthrate                     3053 non-null   float64
#  32  industry_share_manufacturing  3053 non-null   float64
#  33  industry_share_mineoilgas     3053 non-null   float64
#  34  uv                            3031 non-null   float64
#  35  poppct_urban                  3053 non-null   float64
#  36  poppct_rural                  3053 non-null   float64
#  37  ratioemployment               3053 non-null   float64
#  38  ratiocoverage                 3053 non-null   float64
# dtypes: float64(36), int64(3)
# memory usage: 954.1 KB

# %%
# Bin each column and write ordinary integers into each row
dfnum_bins = pd.DataFrame()
for i, column in enumerate(dfnum):
    dfnum_bins[column + 'q'] = pd.qcut(dfnum[column],5,duplicates='drop',labels=False)
print (dfnum)
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3048  1962.667684                15             149.6     453.549422
# 3049  1962.667684                43             150.1     453.549422
# 3050  1962.667684                46             153.9     453.549422
# 3051  1962.667684                52             175.0     453.549422
# 3052  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap  medianage  \
# 0         61898      260131            11.2   499.748204       39.3
# 1         48127       43269            18.6    23.111234       33.0
# 2         49348       21026            14.6    47.560164       45.0
# 3         44243       75882            17.1   342.637253       42.8
# 4         49955       10321            12.5     0.000000       48.3
# ...         ...         ...             ...          ...        ...
# 3048      46961        6343            12.4     0.000000       44.2
# 3049      48609       37118            18.8   377.175494       30.4
# 3050      51144       34536            15.0  1968.959926       30.9
# 3051      50745       25609            13.3     0.000000       39.0
# 3052      41193       37030            13.9     0.000000       26.2
#
#       medianagemale  ...  pctotherrace  pctmarriedhouseholds  birthrate  \
# 0              36.9  ...      1.843479             52.856076   6.118831
# 1              32.2  ...      3.741352             45.372500   4.333096
# 2              44.0  ...      2.747358             54.444868   3.729488
# 3              42.2  ...      1.362643             51.021514   4.603841
# 4              47.8  ...      0.492135             54.027460   6.796657
# ...             ...  ...           ...                   ...        ...
# 3048           41.1  ...      1.700468             51.063830   7.773512
# 3049           29.3  ...     14.130288             52.007937   8.186470
# 3050           30.5  ...      5.680705             55.153949   7.809192
# 3051           36.9  ...      2.131790             58.484232   7.582938
# 3052           25.5  ...      1.356457             56.040242   8.981723
#
#       industry_share_manufacturing  industry_share_mineoilgas      uv  \
# 0                         2.542714                   0.050196  3244.0
# 1                         3.068327                   0.006207  3806.0
# 2                        18.080733                   0.098422  4051.0
# 3                        10.155325                   1.170562  3425.0
# 4                         0.000000                   0.326622  3870.0
# ...                            ...                        ...     ...
# 3048                     15.817909                   3.937987  4581.0
# 3049                     21.138494                   2.354351  4873.0
# 3050                     31.452893                   0.308944  4848.0
# 3051                     12.407903                   0.694306  4322.0
# 3052                      2.724209                   0.003446  4391.0
#
#       poppct_urban  poppct_rural  ratioemployment  ratiocoverage
# 0            83.26         16.74         5.829581       1.208875
# 1            59.94         40.06         5.829581       1.208875
# 2            39.79         60.21         5.829581       1.208875
# 3            39.35         60.65         5.829581       1.208875
# 4             0.00        100.00         5.829581       1.208875
# ...            ...           ...              ...            ...
# 3048         45.90         54.10        13.217273       1.226752
# 3049         81.42         18.58        13.217273       1.226752
# 3050         80.70         19.30        13.217273       1.226752
# 3051         47.90         52.10        13.217273       1.226752
# 3052         88.33         11.67        13.217273       1.226752
#
# [3053 rows x 39 columns]

# %%
# check for missing values
dfnum_bins.isnull().sum()
# Out:
# avganncountq                      0
# avgdeathsperyearq                 0
# target_deathrateq                 0
# incidencerateq                    0
# medincomeq                        0
# popest2015q                       0
# povertypercentq                   0
# studypercapq                      0
# medianageq                        0
# medianagemaleq                    0
# medianagefemaleq                  0
# avghouseholdsizeq                 0
# percentmarriedq                   0
# pctnohs18_24q                     0
# pcths18_24q                       0
# pctsomecol18_24q                  0
# pctbachdeg18_24q                  0
# pcths25_overq                     0
# pctbachdeg25_overq                0
# pctemployed16_overq               0
# pctunemployed16_overq             0
# pctprivatecoverageq               0
# pctprivatecoveragealoneq          0
# pctempprivcoverageq               0
# pctpubliccoverageq                0
# pctpubliccoveragealoneq           0
# pctwhiteq                         0
# pctblackq                         0
# pctasianq                         0
# pctotherraceq                     0
# pctmarriedhouseholdsq             0
# birthrateq                        0
# industry_share_manufacturingq     0
# industry_share_mineoilgasq        0
# uvq                              22
# poppct_urbanq                     0
# poppct_ruralq                     0
# ratioemploymentq                  0
# ratiocoverageq                    0
# dtype: int64

# %%
# check for missing values
dfnum_bins.max()
# Out:
# avganncountq                     4.0
# avgdeathsperyearq                4.0
# target_deathrateq                4.0
# incidencerateq                   4.0
# medincomeq                       4.0
# popest2015q                      4.0
# povertypercentq                  4.0
# studypercapq                     1.0
# medianageq                       4.0
# medianagemaleq                   4.0
# medianagefemaleq                 4.0
# avghouseholdsizeq                4.0
# percentmarriedq                  4.0
# pctnohs18_24q                    4.0
# pcths18_24q                      4.0
# pctsomecol18_24q                 4.0
# pctbachdeg18_24q                 4.0
# pcths25_overq                    4.0
# pctbachdeg25_overq               4.0
# pctemployed16_overq              4.0
# pctunemployed16_overq            4.0
# pctprivatecoverageq              4.0
# pctprivatecoveragealoneq         4.0
# pctempprivcoverageq              4.0
# pctpubliccoverageq               4.0
# pctpubliccoveragealoneq          4.0
# pctwhiteq                        4.0
# pctblackq                        4.0
# pctasianq                        4.0
# pctotherraceq                    4.0
# pctmarriedhouseholdsq            4.0
# birthrateq                       4.0
# industry_share_manufacturingq    4.0
# industry_share_mineoilgasq       4.0
# uvq                              4.0
# poppct_urbanq                    3.0
# poppct_ruralq                    3.0
# ratioemploymentq                 4.0
# ratiocoverageq                   4.0
# dtype: float64

# %% [markdown]
# ## 2.4 Outliers

# %%
# Move numericals to dedicated dataframe
numerical = data_main.select_dtypes('number')

# %% [markdown]
# ### Checking for Outliers

# %%
Q1 = numerical.quantile(0.25)
Q3 = numerical.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# avganncount                       443.000000
# avgdeathsperyear                  121.000000
# target_deathrate                   34.000000
# incidencerate                      60.500000
# medincome                       13626.000000
# popest2015                      57176.000000
# povertypercent                      8.300000
# studypercap                        83.840677
# medianage                           6.300000
# medianagemale                       6.100000
# medianagefemale                     6.200000
# avghouseholdsize                    0.260000
# percentmarried                      8.700000
# pctnohs18_24                        9.900000
# pcths18_24                         11.500000
# pctsomecol18_24                    12.800000
# pctbachdeg18_24                     5.100000
# pcths25_over                        9.200000
# pctbachdeg25_over                   6.700000
# pctemployed16_over                 12.100000
# pctunemployed16_over                4.200000
# pctprivatecoverage                 14.900000
# pctprivatecoveragealone            14.600000
# pctempprivcoverage                 13.200000
# pctpubliccoverage                  10.700000
# pctpubliccoveragealone              8.300000
# pctwhite                           18.177710
# pctblack                            9.908999
# pctasian                            0.969044
# pctotherrace                        1.880847
# pctmarriedhouseholds                7.639704
# birthrate                           1.968305
# industry_share_manufacturing       17.214232
# industry_share_mineoilgas           1.804652
# uv                                612.000000
# poppct_urban                       51.910000
# poppct_rural                       51.910000
# ratioemployment                     3.225038
# ratiocoverage                       0.056705
# dtype: float64

# %%
# counting outliers
((numerical < (Q1 - 1.5 * IQR)) | (numerical > (Q3 + 1.5 * IQR))).sum()
# Out:
# avganncount                     464
# avgdeathsperyear                352
# target_deathrate                 64
# incidencerate                    93
# medincome                       123
# popest2015                      413
# povertypercent                   69
# studypercap                     505
# medianage                        93
# medianagemale                    92
# medianagefemale                  78
# avghouseholdsize                201
# percentmarried                   68
# pctnohs18_24                     69
# pcths18_24                       52
# pctsomecol18_24                 110
# pctbachdeg18_24                  95
# pcths25_over                     32
# pctbachdeg25_over                83
# pctemployed16_over               45
# pctunemployed16_over             68
# pctprivatecoverage               21
# pctprivatecoveragealone           5
# pctempprivcoverage                9
# pctpubliccoverage                17
# pctpubliccoveragealone           35
# pctwhite                        174
# pctblack                        393
# pctasian                        327
# pctotherrace                    297
# pctmarriedhouseholds            100
# birthrate                       165
# industry_share_manufacturing     88
# industry_share_mineoilgas       553
# uv                               31
# poppct_urban                      0
# poppct_rural                      0
# ratioemployment                 253
# ratiocoverage                   298
# dtype: int64

# %% [markdown]
# ### Deleting Outliers from Dataframe

# %%
numerical_o = numerical[~((numerical < (Q1 - 3 * IQR)) |(numerical > (Q3 + 3 * IQR))).any(axis=1)]
print(numerical.shape)
print(numerical_o.shape)
# Out:
# (3053, 39)
# (1577, 39)

# %%
# check
numerical_o.describe()
# Out:
#        avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count  1577.000000       1577.000000       1577.000000    1577.000000
# mean    222.107166         89.548510        181.508941     450.037096
# std     223.858983         85.654714         26.075676      49.409672
# min       9.000000          3.000000         80.800000     259.000000
# 25%      74.000000         32.000000        165.100000     420.400000
# 50%     143.000000         60.000000        181.600000     455.100000
# 75%     275.000000        113.000000        198.100000     483.400000
# max    1385.000000        509.000000        292.500000     639.700000
#
#           medincome     popest2015  povertypercent  studypercap    medianage  \
# count   1577.000000    1577.000000     1577.000000  1577.000000  1577.000000
# mean   45763.245403   41745.293595       16.662080    28.184130    41.744325
# std    10104.047827   44250.262953        5.568417    65.210079     4.893795
# min    23047.000000    1358.000000        4.300000     0.000000    22.300000
# 25%    38504.000000   12682.000000       12.400000     0.000000    39.100000
# 50%    44109.000000   25653.000000       16.100000     0.000000    41.700000
# 75%    51221.000000   51540.000000       20.100000     9.606979    44.400000
# max    92647.000000  235429.000000       45.100000   335.181127    59.000000
#
#        medianagemale  ...  pctotherrace  pctmarriedhouseholds    birthrate  \
# count    1577.000000  ...   1577.000000           1577.000000  1577.000000
# mean       40.512682  ...      1.200152             52.473082     5.515271
# std         4.938338  ...      1.429829              5.321378     1.741966
# min        22.400000  ...      0.000000             30.507696     0.000000
# 25%        37.700000  ...      0.254615             49.221790     4.451141
# 50%        40.300000  ...      0.660907             52.372139     5.354924
# 75%        43.100000  ...      1.593011             55.733524     6.422857
# max        60.200000  ...      7.802114             78.075397    12.146423
#
#        industry_share_manufacturing  industry_share_mineoilgas           uv  \
# count                   1577.000000                1577.000000  1572.000000
# mean                      16.230627                   0.868549  4240.516750
# std                       13.609545                   1.512604   360.534173
# min                        0.000000                   0.000000  3012.000000
# 25%                        5.442651                   0.010385  3982.250000
# 50%                       13.848763                   0.210525  4223.000000
# 75%                       23.686488                   0.892914  4485.000000
# max                       70.276519                   7.243187  5723.000000
#
#        poppct_urban  poppct_rural  ratioemployment  ratiocoverage
# count   1577.000000   1577.000000      1577.000000    1577.000000
# mean      35.106240     64.893767         7.406601       1.177785
# std       26.374131     26.374126         3.155476       0.058179
# min        0.000000      0.000000         3.791086       1.056429
# 25%       11.070000     44.490000         5.207784       1.140009
# 50%       34.940000     65.060000         7.025973       1.175327
# 75%       55.510000     88.930000         7.808807       1.196714
# max      100.000000    100.000000        17.912889       1.324858
#
# [8 rows x 39 columns]

# %% [markdown]
# # 3. Data Exploring

# %% [markdown]
# ## 3.1 Check for correlations

# %%
# calculate new Dataframe with correllation factors
corr_df = numerical.corr().abs()
corr_df
# Out:
#                               avganncount  avgdeathsperyear  target_deathrate  \
# avganncount                      1.000000          0.939918          0.144951
# avgdeathsperyear                 0.939918          1.000000          0.092301
# target_deathrate                 0.144951          0.092301          1.000000
# incidencerate                    0.073584          0.062896          0.449761
# medincome                        0.273397          0.227594          0.429781
# popest2015                       0.927175          0.977339          0.122027
# povertypercent                   0.138545          0.070157          0.430162
# studypercap                      0.082352          0.063840          0.022199
# medianage                        0.024377          0.024874          0.004520
# medianagemale                    0.125670          0.148995          0.021795
# medianagefemale                  0.123342          0.144338          0.012195
# avghouseholdsize                 0.065240          0.086424          0.037296
# percentmarried                   0.106380          0.181024          0.267030
# pctnohs18_24                     0.144851          0.138475          0.089293
# pcths18_24                       0.183640          0.153074          0.262576
# pctsomecol18_24                  0.139299          0.119477          0.162922
# pctbachdeg18_24                  0.288145          0.263730          0.289394
# pcths25_over                     0.314773          0.299276          0.405831
# pctbachdeg25_over                0.324857          0.297128          0.486322
# pctemployed16_over               0.117848          0.069737          0.193410
# pctunemployed16_over             0.010018          0.068338          0.378875
# pctprivatecoverage               0.134872          0.059260          0.387008
# pctprivatecoveragealone          0.196498          0.137286          0.363616
# pctempprivcoverage               0.205291          0.163325          0.268484
# pctpubliccoverage                0.176605          0.134877          0.405683
# pctpubliccoveragealone           0.096424          0.030358          0.450316
# pctwhite                         0.138809          0.189186          0.176219
# pctblack                         0.033365          0.086461          0.256399
# pctasian                         0.437467          0.444884          0.189125
# pctotherrace                     0.208159          0.213940          0.189849
# pctmarriedhouseholds             0.106485          0.160399          0.293685
# birthrate                        0.035195          0.074890          0.087195
# industry_share_manufacturing     0.048441          0.042282          0.176478
# industry_share_mineoilgas        0.086739          0.090827          0.027988
# uv                               0.001416          0.008356          0.072103
# poppct_urban                     0.382471          0.421055          0.152400
# poppct_rural                     0.382471          0.421055          0.152399
# ratioemployment                  0.004333          0.116253          0.295772
# ratiocoverage                    0.080947          0.116152          0.247617
#
#                               incidencerate  medincome  popest2015  \
# avganncount                        0.073584   0.273397    0.927175
# avgdeathsperyear                   0.062896   0.227594    0.977339
# target_deathrate                   0.449761   0.429781    0.122027
# incidencerate                      1.000000   0.002983    0.026543
# medincome                          0.002983   1.000000    0.241014
# popest2015                         0.026543   0.241014    1.000000
# povertypercent                     0.009644   0.788096    0.068460
# studypercap                        0.077462   0.043892    0.055993
# medianage                          0.018113   0.013641    0.025500
# medianagemale                      0.014901   0.092321    0.177156
# medianagefemale                    0.009071   0.153730    0.178335
# avghouseholdsize                   0.118565   0.112918    0.110482
# percentmarried                     0.120204   0.353781    0.160138
# pctnohs18_24                       0.170319   0.289743    0.128025
# pcths18_24                         0.022797   0.191684    0.153694
# pctsomecol18_24                    0.087865   0.166338    0.116787
# pctbachdeg18_24                    0.045497   0.496623    0.252921
# pcths25_over                       0.122399   0.474672    0.315519
# pctbachdeg25_over                  0.039143   0.706634    0.301654
# pctemployed16_over                 0.021730   0.393819    0.080852
# pctunemployed16_over               0.100476   0.452531    0.049375
# pctprivatecoverage                 0.104310   0.723616    0.055741
# pctprivatecoveragealone            0.106373   0.775017    0.144178
# pctempprivcoverage                 0.149096   0.746667    0.161709
# pctpubliccoverage                  0.046856   0.755038    0.163441
# pctpubliccoveragealone             0.041597   0.719674    0.044671
# pctwhite                           0.014541   0.163272    0.192125
# pctblack                           0.113863   0.267764    0.074390
# pctasian                           0.010291   0.432917    0.467672
# pctotherrace                       0.208821   0.083946    0.240801
# pctmarriedhouseholds               0.152969   0.444700    0.127573
# birthrate                          0.118056   0.010885    0.058221
# industry_share_manufacturing       0.168961   0.050322    0.048173
# industry_share_mineoilgas          0.167899   0.019435    0.079033
# uv                                 0.309579   0.171143    0.040640
# poppct_urban                       0.101255   0.371444    0.393590
# poppct_rural                       0.101255   0.371444    0.393590
# ratioemployment                    0.081164   0.255651    0.098813
# ratiocoverage                      0.177092   0.014595    0.090328
#
#                               povertypercent  studypercap  medianage  \
# avganncount                         0.138545     0.082352   0.024377
# avgdeathsperyear                    0.070157     0.063840   0.024874
# target_deathrate                    0.430162     0.022199   0.004520
# incidencerate                       0.009644     0.077462   0.018113
# medincome                           0.788096     0.043892   0.013641
# popest2015                          0.068460     0.055993   0.025500
# povertypercent                      1.000000     0.055694   0.029052
# studypercap                         0.055694     1.000000   0.026040
# medianage                           0.029052     0.026040   1.000000
# medianagemale                       0.213342     0.036846   0.129130
# medianagefemale                     0.147447     0.030822   0.124633
# avghouseholdsize                    0.073816     0.004032   0.031990
# percentmarried                      0.642036     0.038281   0.046365
# pctnohs18_24                        0.288907     0.090274   0.006299
# pcths18_24                          0.095085     0.057092   0.050684
# pctsomecol18_24                     0.130400     0.087232   0.039349
# pctbachdeg18_24                     0.389103     0.063904   0.017183
# pcths25_over                        0.196945     0.085107   0.036788
# pctbachdeg25_over                   0.533053     0.108477   0.020620
# pctemployed16_over                  0.385865     0.049424   0.022020
# pctunemployed16_over                0.655199     0.031883   0.018659
# pctprivatecoverage                  0.822772     0.092403   0.004455
# pctprivatecoveragealone             0.747498     0.095921   0.033012
# pctempprivcoverage                  0.683774     0.100042   0.037097
# pctpubliccoverage                   0.651871     0.051507   0.049221
# pctpubliccoveragealone              0.798930     0.055449   0.003096
# pctwhite                            0.507292     0.023154   0.035145
# pctblack                            0.510048     0.019678   0.017265
# pctasian                            0.160451     0.062190   0.038620
# pctotherrace                        0.047080     0.015193   0.030274
# pctmarriedhouseholds                0.604123     0.051932   0.014492
# birthrate                           0.011723     0.010474   0.008260
# industry_share_manufacturing        0.025705     0.009157   0.014353
# industry_share_mineoilgas           0.000618     0.066220   0.000167
# uv                                  0.267619     0.069251   0.025663
# poppct_urban                        0.141212     0.114714   0.061148
# poppct_rural                        0.141212     0.114714   0.061148
# ratioemployment                     0.414858     0.080641   0.007175
# ratiocoverage                       0.066160     0.009041   0.032535
#
#                               medianagemale  ...  pctotherrace  \
# avganncount                        0.125670  ...      0.208159
# avgdeathsperyear                   0.148995  ...      0.213940
# target_deathrate                   0.021795  ...      0.189849
# incidencerate                      0.014901  ...      0.208821
# medincome                          0.092321  ...      0.083946
# popest2015                         0.177156  ...      0.240801
# povertypercent                     0.213342  ...      0.047080
# studypercap                        0.036846  ...      0.015193
# medianage                          0.129130  ...      0.030274
# medianagemale                      1.000000  ...      0.266810
# medianagefemale                    0.933436  ...      0.274382
# avghouseholdsize                   0.343342  ...      0.229620
# percentmarried                     0.450000  ...      0.104431
# pctnohs18_24                       0.100231  ...      0.126482
# pcths18_24                         0.241564  ...      0.060516
# pctsomecol18_24                    0.258802  ...      0.046072
# pctbachdeg18_24                    0.035065  ...      0.006972
# pcths25_over                       0.317989  ...      0.285053
# pctbachdeg25_over                  0.131921  ...      0.039133
# pctemployed16_over                 0.163755  ...      0.021249
# pctunemployed16_over               0.142704  ...      0.028444
# pctprivatecoverage                 0.081923  ...      0.176237
# pctprivatecoveragealone            0.182179  ...      0.081508
# pctempprivcoverage                 0.208732  ...      0.064292
# pctpubliccoverage                  0.398751  ...      0.078741
# pctpubliccoveragealone             0.002759  ...      0.083574
# pctwhite                           0.398164  ...      0.233492
# pctblack                           0.242709  ...      0.023327
# pctasian                           0.238019  ...      0.200351
# pctotherrace                       0.266810  ...      1.000000
# pctmarriedhouseholds               0.222406  ...      0.027066
# birthrate                          0.103784  ...      0.059617
# industry_share_manufacturing       0.062164  ...      0.115110
# industry_share_mineoilgas          0.043833  ...      0.214702
# uv                                 0.212213  ...      0.377417
# poppct_urban                       0.504433  ...      0.256075
# poppct_rural                       0.504433  ...      0.256075
# ratioemployment                    0.109727  ...      0.091794
# ratiocoverage                      0.072598  ...      0.006898
#
#                               pctmarriedhouseholds  birthrate  \
# avganncount                               0.106485   0.035195
# avgdeathsperyear                          0.160399   0.074890
# target_deathrate                          0.293685   0.087195
# incidencerate                             0.152969   0.118056
# medincome                                 0.444700   0.010885
# popest2015                                0.127573   0.058221
# povertypercent                            0.604123   0.011723
# studypercap                               0.051932   0.010474
# medianage                                 0.014492   0.008260
# medianagemale                             0.222406   0.103784
# medianagefemale                           0.161328   0.097844
# avghouseholdsize                          0.091552   0.075801
# percentmarried                            0.870287   0.140995
# pctnohs18_24                              0.005221   0.125825
# pcths18_24                                0.119861   0.058011
# pctsomecol18_24                           0.103011   0.088566
# pctbachdeg18_24                           0.000423   0.125690
# pcths25_over                              0.061297   0.017356
# pctbachdeg25_over                         0.098269   0.088547
# pctemployed16_over                        0.126021   0.071054
# pctunemployed16_over                      0.469664   0.067648
# pctprivatecoverage                        0.434146   0.040366
# pctprivatecoveragealone                   0.370820   0.048455
# pctempprivcoverage                        0.321947   0.093938
# pctpubliccoverage                         0.361935   0.030198
# pctpubliccoveragealone                    0.473745   0.004601
# pctwhite                                  0.596211   0.009238
# pctblack                                  0.573517   0.067213
# pctasian                                  0.084345   0.061853
# pctotherrace                              0.027066   0.059617
# pctmarriedhouseholds                      1.000000   0.102198
# birthrate                                 0.102198   1.000000
# industry_share_manufacturing              0.004022   0.023156
# industry_share_mineoilgas                 0.083212   0.103553
# uv                                        0.056216   0.077470
# poppct_urban                              0.228949   0.071216
# poppct_rural                              0.228949   0.071216
# ratioemployment                           0.236109   0.227345
# ratiocoverage                             0.088999   0.199324
#
#                               industry_share_manufacturing  \
# avganncount                                       0.048441
# avgdeathsperyear                                  0.042282
# target_deathrate                                  0.176478
# incidencerate                                     0.168961
# medincome                                         0.050322
# popest2015                                        0.048173
# povertypercent                                    0.025705
# studypercap                                       0.009157
# medianage                                         0.014353
# medianagemale                                     0.062164
# medianagefemale                                   0.054931
# avghouseholdsize                                  0.011518
# percentmarried                                    0.010576
# pctnohs18_24                                      0.052692
# pcths18_24                                        0.043422
# pctsomecol18_24                                   0.025336
# pctbachdeg18_24                                   0.054192
# pcths25_over                                      0.226225
# pctbachdeg25_over                                 0.157759
# pctemployed16_over                                0.024743
# pctunemployed16_over                              0.066304
# pctprivatecoverage                                0.056064
# pctprivatecoveragealone                           0.094198
# pctempprivcoverage                                0.169242
# pctpubliccoverage                                 0.010790
# pctpubliccoveragealone                            0.011947
# pctwhite                                          0.025897
# pctblack                                          0.088150
# pctasian                                          0.052612
# pctotherrace                                      0.115110
# pctmarriedhouseholds                              0.004022
# birthrate                                         0.023156
# industry_share_manufacturing                      1.000000
# industry_share_mineoilgas                         0.232494
# uv                                                0.178932
# poppct_urban                                      0.073438
# poppct_rural                                      0.073438
# ratioemployment                                   0.104701
# ratiocoverage                                     0.186138
#
#                               industry_share_mineoilgas        uv  \
# avganncount                                    0.086739  0.001416
# avgdeathsperyear                               0.090827  0.008356
# target_deathrate                               0.027988  0.072103
# incidencerate                                  0.167899  0.309579
# medincome                                      0.019435  0.171143
# popest2015                                     0.079033  0.040640
# povertypercent                                 0.000618  0.267619
# studypercap                                    0.066220  0.069251
# medianage                                      0.000167  0.025663
# medianagemale                                  0.043833  0.212213
# medianagefemale                                0.053170  0.185791
# avghouseholdsize                               0.086280  0.191321
# percentmarried                                 0.059883  0.130409
# pctnohs18_24                                   0.136177  0.245875
# pcths18_24                                     0.114731  0.006610
# pctsomecol18_24                                0.140413  0.097740
# pctbachdeg18_24                                0.132137  0.214263
# pcths25_over                                   0.072438  0.206627
# pctbachdeg25_over                              0.144507  0.113578
# pctemployed16_over                             0.042071  0.137630
# pctunemployed16_over                           0.071365  0.125653
# pctprivatecoverage                             0.108356  0.390408
# pctprivatecoveragealone                        0.075723  0.313690
# pctempprivcoverage                             0.041858  0.338532
# pctpubliccoverage                              0.051319  0.044617
# pctpubliccoveragealone                         0.018482  0.180459
# pctwhite                                       0.026251  0.296430
# pctblack                                       0.089222  0.209901
# pctasian                                       0.098414  0.013750
# pctotherrace                                   0.214702  0.377417
# pctmarriedhouseholds                           0.083212  0.056216
# birthrate                                      0.103553  0.077470
# industry_share_manufacturing                   0.232494  0.178932
# industry_share_mineoilgas                      1.000000  0.243176
# uv                                             0.243176  1.000000
# poppct_urban                                   0.089512  0.047268
# poppct_rural                                   0.089512  0.047268
# ratioemployment                                0.016842  0.199126
# ratiocoverage                                  0.044056  0.175369
#
#                               poppct_urban  poppct_rural  ratioemployment  \
# avganncount                       0.382471      0.382471         0.004333
# avgdeathsperyear                  0.421055      0.421055         0.116253
# target_deathrate                  0.152400      0.152399         0.295772
# incidencerate                     0.101255      0.101255         0.081164
# medincome                         0.371444      0.371444         0.255651
# popest2015                        0.393590      0.393590         0.098813
# povertypercent                    0.141212      0.141212         0.414858
# studypercap                       0.114714      0.114714         0.080641
# medianage                         0.061148      0.061148         0.007175
# medianagemale                     0.504433      0.504433         0.109727
# medianagefemale                   0.485980      0.485980         0.094908
# avghouseholdsize                  0.134965      0.134965         0.115336
# percentmarried                    0.307424      0.307424         0.383320
# pctnohs18_24                      0.278635      0.278635         0.086767
# pcths18_24                        0.269578      0.269578         0.152677
# pctsomecol18_24                   0.299463      0.299463         0.106768
# pctbachdeg18_24                   0.310455      0.310455         0.201249
# pcths25_over                      0.515080      0.515080         0.055393
# pctbachdeg25_over                 0.468665      0.468665         0.232732
# pctemployed16_over                0.171369      0.171369         0.397166
# pctunemployed16_over              0.025315      0.025315         0.572341
# pctprivatecoverage                0.201654      0.201653         0.454492
# pctprivatecoveragealone           0.336036      0.336036         0.384744
# pctempprivcoverage                0.377040      0.377040         0.244139
# pctpubliccoverage                 0.377969      0.377969         0.320475
# pctpubliccoveragealone            0.185148      0.185148         0.445618
# pctwhite                          0.199931      0.199931         0.308431
# pctblack                          0.095995      0.095996         0.360182
# pctasian                          0.437615      0.437615         0.065197
# pctotherrace                      0.256075      0.256075         0.091794
# pctmarriedhouseholds              0.228949      0.228949         0.236109
# birthrate                         0.071216      0.071216         0.227345
# industry_share_manufacturing      0.073438      0.073438         0.104701
# industry_share_mineoilgas         0.089512      0.089512         0.016842
# uv                                0.047268      0.047268         0.199126
# poppct_urban                      1.000000      1.000000         0.121737
# poppct_rural                      1.000000      1.000000         0.121737
# ratioemployment                   0.121737      0.121737         1.000000
# ratiocoverage                     0.150653      0.150653         0.496538
#
#                               ratiocoverage
# avganncount                        0.080947
# avgdeathsperyear                   0.116152
# target_deathrate                   0.247617
# incidencerate                      0.177092
# medincome                          0.014595
# popest2015                         0.090328
# povertypercent                     0.066160
# studypercap                        0.009041
# medianage                          0.032535
# medianagemale                      0.072598
# medianagefemale                    0.071619
# avghouseholdsize                   0.040160
# percentmarried                     0.196066
# pctnohs18_24                       0.098040
# pcths18_24                         0.097235
# pctsomecol18_24                    0.008736
# pctbachdeg18_24                    0.001625
# pcths25_over                       0.213018
# pctbachdeg25_over                  0.162125
# pctemployed16_over                 0.154675
# pctunemployed16_over               0.236418
# pctprivatecoverage                 0.066407
# pctprivatecoveragealone            0.028679
# pctempprivcoverage                 0.185362
# pctpubliccoverage                  0.123058
# pctpubliccoveragealone             0.179714
# pctwhite                           0.010808
# pctblack                           0.067924
# pctasian                           0.102182
# pctotherrace                       0.006898
# pctmarriedhouseholds               0.088999
# birthrate                          0.199324
# industry_share_manufacturing       0.186138
# industry_share_mineoilgas          0.044056
# uv                                 0.175369
# poppct_urban                       0.150653
# poppct_rural                       0.150653
# ratioemployment                    0.496538
# ratiocoverage                      1.000000
#
# [39 rows x 39 columns]

# %%
# Plot correlation heatmap
fig = plt.figure(figsize = (20,15))
ax = sns.heatmap(corr_df.round(2), annot=True, annot_kws={"size": 8})
plt.savefig('pics/corr_heatmap.png')

# %% [markdown]
# ### Filtering out highly correlated features

# %%
# Select upper traingular
upper_tri = corr_df.where(np.triu(np.ones(corr_df.shape),k=1).astype(np.bool_))
# Save highly correlating features r>0.9 in the list to_drop
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
# Drop the features from the to_drop list and create a reduced DataFrame
reduced_df = numerical.drop(numerical[to_drop], axis=1)

print("The reduced dataframe has {} columns.".format(reduced_df.shape[1]))
# Out:
# The reduced dataframe has 33 columns.

# %%
to_drop
# Out:
# ['avgdeathsperyear',
#  'popest2015',
#  'medianagefemale',
#  'pctprivatecoveragealone',
#  'pctempprivcoverage',
#  'poppct_rural']

# %% [markdown]
# ## 3.1 Building graphs

# %% [markdown]
# ### Histograms

# %%
   fig = plt.figure(figsize = (15,20))
   ax = fig.gca()
   reduced_df.hist(ax = ax)
# Out:
# C:\Users\flanc\AppData\Local\Temp/ipykernel_19116/3306283368.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   reduced_df.hist(ax = ax)
# array([[<AxesSubplot:title={'center':'avganncount'}>,
#         <AxesSubplot:title={'center':'target_deathrate'}>,
#         <AxesSubplot:title={'center':'incidencerate'}>,
#         <AxesSubplot:title={'center':'medincome'}>,
#         <AxesSubplot:title={'center':'povertypercent'}>,
#         <AxesSubplot:title={'center':'studypercap'}>],
#        [<AxesSubplot:title={'center':'medianage'}>,
#         <AxesSubplot:title={'center':'medianagemale'}>,
#         <AxesSubplot:title={'center':'avghouseholdsize'}>,
#         <AxesSubplot:title={'center':'percentmarried'}>,
#         <AxesSubplot:title={'center':'pctnohs18_24'}>,
#         <AxesSubplot:title={'center':'pcths18_24'}>],
#        [<AxesSubplot:title={'center':'pctsomecol18_24'}>,
#         <AxesSubplot:title={'center':'pctbachdeg18_24'}>,
#         <AxesSubplot:title={'center':'pcths25_over'}>,
#         <AxesSubplot:title={'center':'pctbachdeg25_over'}>,
#         <AxesSubplot:title={'center':'pctemployed16_over'}>,
#         <AxesSubplot:title={'center':'pctunemployed16_over'}>],
#        [<AxesSubplot:title={'center':'pctprivatecoverage'}>,
#         <AxesSubplot:title={'center':'pctpubliccoverage'}>,
#         <AxesSubplot:title={'center':'pctpubliccoveragealone'}>,
#         <AxesSubplot:title={'center':'pctwhite'}>,
#         <AxesSubplot:title={'center':'pctblack'}>,
#         <AxesSubplot:title={'center':'pctasian'}>],
#        [<AxesSubplot:title={'center':'pctotherrace'}>,
#         <AxesSubplot:title={'center':'pctmarriedhouseholds'}>,
#         <AxesSubplot:title={'center':'birthrate'}>,
#         <AxesSubplot:title={'center':'industry_share_manufacturing'}>,
#         <AxesSubplot:title={'center':'industry_share_mineoilgas'}>,
#         <AxesSubplot:title={'center':'uv'}>],
#        [<AxesSubplot:title={'center':'poppct_urban'}>,
#         <AxesSubplot:title={'center':'ratioemployment'}>,
#         <AxesSubplot:title={'center':'ratiocoverage'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Pairplots

# %%
# Pairplot for each numerical column
#sns.pairplot(numerical)

# %%
# check histogramms after loosing the outliers
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
numerical_o.hist(ax = ax)
# Out:
# C:\Users\flanc\AppData\Local\Temp/ipykernel_19116/1224258567.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   numerical_o.hist(ax = ax)
# array([[<AxesSubplot:title={'center':'avganncount'}>,
#         <AxesSubplot:title={'center':'avgdeathsperyear'}>,
#         <AxesSubplot:title={'center':'target_deathrate'}>,
#         <AxesSubplot:title={'center':'incidencerate'}>,
#         <AxesSubplot:title={'center':'medincome'}>,
#         <AxesSubplot:title={'center':'popest2015'}>],
#        [<AxesSubplot:title={'center':'povertypercent'}>,
#         <AxesSubplot:title={'center':'studypercap'}>,
#         <AxesSubplot:title={'center':'medianage'}>,
#         <AxesSubplot:title={'center':'medianagemale'}>,
#         <AxesSubplot:title={'center':'medianagefemale'}>,
#         <AxesSubplot:title={'center':'avghouseholdsize'}>],
#        [<AxesSubplot:title={'center':'percentmarried'}>,
#         <AxesSubplot:title={'center':'pctnohs18_24'}>,
#         <AxesSubplot:title={'center':'pcths18_24'}>,
#         <AxesSubplot:title={'center':'pctsomecol18_24'}>,
#         <AxesSubplot:title={'center':'pctbachdeg18_24'}>,
#         <AxesSubplot:title={'center':'pcths25_over'}>],
#        [<AxesSubplot:title={'center':'pctbachdeg25_over'}>,
#         <AxesSubplot:title={'center':'pctemployed16_over'}>,
#         <AxesSubplot:title={'center':'pctunemployed16_over'}>,
#         <AxesSubplot:title={'center':'pctprivatecoverage'}>,
#         <AxesSubplot:title={'center':'pctprivatecoveragealone'}>,
#         <AxesSubplot:title={'center':'pctempprivcoverage'}>],
#        [<AxesSubplot:title={'center':'pctpubliccoverage'}>,
#         <AxesSubplot:title={'center':'pctpubliccoveragealone'}>,
#         <AxesSubplot:title={'center':'pctwhite'}>,
#         <AxesSubplot:title={'center':'pctblack'}>,
#         <AxesSubplot:title={'center':'pctasian'}>,
#         <AxesSubplot:title={'center':'pctotherrace'}>],
#        [<AxesSubplot:title={'center':'pctmarriedhouseholds'}>,
#         <AxesSubplot:title={'center':'birthrate'}>,
#         <AxesSubplot:title={'center':'industry_share_manufacturing'}>,
#         <AxesSubplot:title={'center':'industry_share_mineoilgas'}>,
#         <AxesSubplot:title={'center':'uv'}>,
#         <AxesSubplot:title={'center':'poppct_urban'}>],
#        [<AxesSubplot:title={'center':'poppct_rural'}>,
#         <AxesSubplot:title={'center':'ratioemployment'}>,
#         <AxesSubplot:title={'center':'ratiocoverage'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# Fun fact - What are the most common county names
data_main['county'].value_counts().head(10)
# Out:
# Washington    31
# Jefferson     26
# Franklin      25
# Lincoln       24
# Jackson       22
# Madison       20
# Clay          18
# Union         18
# Montgomery    18
# Monroe        17
# Name: county, dtype: int64

# %% [markdown]
# # 4. Linear Regression Modelling

# %% [markdown]
# ### Import Machine Learning Libraries

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3053 entries, 0 to 3052
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avganncount                   3053 non-null   float64
#  1   avgdeathsperyear              3053 non-null   int64
#  2   target_deathrate              3053 non-null   float64
#  3   incidencerate                 3053 non-null   float64
#  4   medincome                     3053 non-null   int64
#  5   popest2015                    3053 non-null   int64
#  6   povertypercent                3053 non-null   float64
#  7   studypercap                   3053 non-null   float64
#  8   medianage                     3053 non-null   float64
#  9   medianagemale                 3053 non-null   float64
#  10  medianagefemale               3053 non-null   float64
#  11  avghouseholdsize              3053 non-null   float64
#  12  percentmarried                3053 non-null   float64
#  13  pctnohs18_24                  3053 non-null   float64
#  14  pcths18_24                    3053 non-null   float64
#  15  pctsomecol18_24               3053 non-null   float64
#  16  pctbachdeg18_24               3053 non-null   float64
#  17  pcths25_over                  3053 non-null   float64
#  18  pctbachdeg25_over             3053 non-null   float64
#  19  pctemployed16_over            3053 non-null   float64
#  20  pctunemployed16_over          3053 non-null   float64
#  21  pctprivatecoverage            3053 non-null   float64
#  22  pctprivatecoveragealone       3053 non-null   float64
#  23  pctempprivcoverage            3053 non-null   float64
#  24  pctpubliccoverage             3053 non-null   float64
#  25  pctpubliccoveragealone        3053 non-null   float64
#  26  pctwhite                      3053 non-null   float64
#  27  pctblack                      3053 non-null   float64
#  28  pctasian                      3053 non-null   float64
#  29  pctotherrace                  3053 non-null   float64
#  30  pctmarriedhouseholds          3053 non-null   float64
#  31  birthrate                     3053 non-null   float64
#  32  industry_share_manufacturing  3053 non-null   float64
#  33  industry_share_mineoilgas     3053 non-null   float64
#  34  uv                            3031 non-null   float64
#  35  poppct_urban                  3053 non-null   float64
#  36  poppct_rural                  3053 non-null   float64
#  37  ratioemployment               3053 non-null   float64
#  38  ratiocoverage                 3053 non-null   float64
# dtypes: float64(36), int64(3)
# memory usage: 954.1 KB

# %% [markdown]
# ## 4.1 Model 1

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X1_raw = numerical.drop(['target_deathrate','ratioemployment','ratiocoverage','uv'], axis=1)
Y1 = numerical['target_deathrate']

# Use Standard_Scaler
X1_array = StandardScaler().fit_transform(X1_raw)
X1 = pd.DataFrame(X1_array, index=X1_raw.index, columns=X1_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, Y1, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# set model to Linear Regression
model1=LinearRegression()
# train the model
model1.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction. plotting, Regression

# %%
y1_pred=model1.predict(X1_test)   # model prediction
y1_pred

result=pd.DataFrame({"y_test":y1_test,"y_pred":y1_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y1_pred, y1_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y1_test - y1_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
# Compute:
# ME: mean error
ME1 = np.mean( y1_test - y1_pred )

# MAE: mean absolute error
MAE1 = np.mean( np.abs( y1_test - y1_pred ) )

# MSE: mean squared error
MSE1 = np.mean( np.power( y1_test - y1_pred , 2 ) )

# RMSE: root mean squared error
RMSE1 = np.sqrt(MSE1)

# MAPE: mean absolute percentual error
MAPE1 = np.mean( np.abs( y1_test - y1_pred) / y1_test ) 

print('mean error: ' + str(round(ME1,2)))
print('mean absolute error: ' + str(round(MAE1,2)))
print('mean squared error: ' + str(round(MSE1,2)))
print('root mean squared error: ' + str(round(RMSE1,2)))
print('mean absolute percentual error: ' + str(round(MAPE1,2)))
# Out:
# mean error: -0.59
# mean absolute error: 14.5
# mean squared error: 368.68
# root mean squared error: 19.2
# mean absolute percentual error: 0.08

# %% [markdown]
# ### Model Summary

# %%
# Sklearn overview
print('------ Lineare Regression -----')
print('Function from sklearn: y = %.3f * x + %.3f' % (model1.coef_[0], model1.intercept_))
print("Alpha: {}".format(model1.intercept_))
print("Beta: {}".format(model1.coef_[0]))
print("Training Set R² Score: {:.2f}".format(model1.score(X1_train, y1_train)))
print("Test Set R² Score: {:.2f}".format(model1.score(X1_test, y1_test)))
print("\n")
# Out:
# ------ Lineare Regression -----
# Function from sklearn: y = -4.918 * x + 178.745
# Alpha: 178.74494902389077
# Beta: -4.917683104653336
# Training Set R² Score: 0.52
# Test Set R² Score: 0.51

# %%
# Stats overview
import statsmodels.api as sm

X_train_const_scaled1 = sm.add_constant(X1_train) # adding a constant

model1_OLS = sm.OLS(y1_train, X_train_const_scaled1).fit()
predictions1 = model1_OLS.predict(X_train_const_scaled1) 

X_test_const_scaled1 = sm.add_constant(X1_test) # adding a constant
print_model1 = model1_OLS.summary()
print(print_model1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       target_deathrate   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     75.17
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        16:51:18   Log-Likelihood:                -10683.
# No. Observations:                2442   AIC:                         2.144e+04
# Df Residuals:                    2406   BIC:                         2.165e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                          178.7449      0.392    455.741      0.000     177.976     179.514
# avganncount                     -4.9177      1.220     -4.029      0.000      -7.311      -2.524
# avgdeathsperyear                10.3762      2.218      4.679      0.000       6.028      14.725
# incidencerate                   10.4084      0.463     22.476      0.000       9.500      11.317
# medincome                        2.7570      1.122      2.456      0.014       0.556       4.958
# popest2015                      -5.8166      1.997     -2.913      0.004      -9.732      -1.901
# povertypercent                   5.2653      1.137      4.629      0.000       3.035       7.496
# studypercap                      0.0367      0.380      0.096      0.923      -0.709       0.782
# medianage                        0.1571      0.405      0.388      0.698      -0.637       0.952
# medianagemale                   -2.8456      1.311     -2.171      0.030      -5.416      -0.275
# medianagefemale                 -0.0612      1.298     -0.047      0.962      -2.606       2.484
# avghouseholdsize                 0.2744      0.445      0.617      0.538      -0.598       1.147
# percentmarried                   7.6298      1.184      6.446      0.000       5.309       9.951
# pctnohs18_24                   -84.9071    110.764     -0.767      0.443    -302.110     132.296
# pcths18_24                     -91.6694    124.129     -0.739      0.460    -335.080     151.741
# pctsomecol18_24               -113.7572    150.385     -0.756      0.449    -408.654     181.140
# pctbachdeg18_24                -47.9248     62.172     -0.771      0.441    -169.840      73.990
# pcths25_over                     2.2693      0.775      2.926      0.003       0.749       3.790
# pctbachdeg25_over               -6.4537      0.940     -6.866      0.000      -8.297      -4.610
# pctemployed16_over              -0.1672      0.486     -0.344      0.731      -1.120       0.786
# pctunemployed16_over             0.6164      0.631      0.977      0.329      -0.621       1.854
# pctprivatecoverage              -4.5196      2.328     -1.941      0.052      -9.085       0.046
# pctprivatecoveragealone         -4.1041      2.493     -1.646      0.100      -8.993       0.785
# pctempprivcoverage               5.3263      1.380      3.860      0.000       2.620       8.032
# pctpubliccoverage               -0.9014      2.306     -0.391      0.696      -5.424       3.621
# pctpubliccoveragealone           0.6463      2.161      0.299      0.765      -3.592       4.885
# pctwhite                        -2.4361      1.092     -2.231      0.026      -4.577      -0.295
# pctblack                        -1.4950      0.950     -1.574      0.116      -3.357       0.367
# pctasian                        -0.2647      0.548     -0.483      0.629      -1.339       0.810
# pctotherrace                    -2.9401      0.516     -5.698      0.000      -3.952      -1.928
# pctmarriedhouseholds            -7.8808      1.094     -7.202      0.000     -10.027      -5.735
# birthrate                       -2.2894      0.423     -5.412      0.000      -3.119      -1.460
# industry_share_manufacturing     0.9279      0.464      1.999      0.046       0.018       1.838
# industry_share_mineoilgas       -0.2268      0.465     -0.488      0.625      -1.138       0.684
# poppct_urban                  2.436e+04   6.07e+04      0.401      0.688   -9.47e+04    1.43e+05
# poppct_rural                  2.437e+04   6.07e+04      0.401      0.688   -9.47e+04    1.43e+05
# ==============================================================================
# Omnibus:                      185.422   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              902.343
# Skew:                           0.162   Prob(JB):                    1.14e-196
# Kurtosis:                       5.960   Cond. No.                     6.62e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.62e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# get coefficient
intercept = model1.intercept_
features = pd.DataFrame(model1.coef_, X1.columns, columns=['coefficient'])
# get standard deviation
stdevs = []
for i in X1.columns:
    stdev = X1[i].std()
    stdevs.append(stdev)
 
features["stdev"] = np.array(stdevs).reshape(-1,1)
features["importance"] = features["coefficient"] * features["stdev"]
features['importance_normalized'] = 100*features['importance'] / features['importance'].max()
plt.barh(features.index, features.importance_normalized)
# Out:
# <BarContainer object of 35 artists>

# %% [markdown]
# ## 4.2 Model 2

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X2_raw = reduced_df.drop(['target_deathrate','ratioemployment','ratiocoverage','uv'], axis=1)
Y2 = reduced_df['target_deathrate']

# Use Standard_Scaler
X2_array = StandardScaler().fit_transform(X2_raw)
X2 = pd.DataFrame(X2_array, index=X2_raw.index, columns=X2_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, Y2, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# set model to Linear Regression
model2=LinearRegression()
# train the model
model2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction, Plotting, metrics

# %%
y2_pred=model2.predict(X2_test)   # model prediction
y2_pred

result2=pd.DataFrame({"y_test":y2_test,"y_pred":y2_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y2_pred, y2_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y2_test - y2_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result2, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
# Compute:
# ME: mean error
ME2 = np.mean( y2_test - y2_pred )

# MAE: mean absolute error
MAE2 = np.mean( np.abs( y2_test - y2_pred ) )

# MSE: mean squared error
MSE2 = np.mean( np.power( y2_test - y2_pred , 2 ) )

# RMSE: root mean squared error
RMSE2 = np.sqrt(MSE2)

# MAPE: mean absolute percentual error
MAPE2 = np.mean( np.abs( y2_test - y2_pred) / y2_test ) 

print('mean error: ' + str(round(ME2,2)))
print('mean absolute error: ' + str(round(MAE2,2)))
print('mean squared error: ' + str(round(MSE2,2)))
print('root mean squared error: ' + str(round(RMSE2,2)))
print('mean absolute percentual error: ' + str(round(MAPE2,2)))
# Out:
# mean error: -0.57
# mean absolute error: 14.57
# mean squared error: 372.3
# root mean squared error: 19.29
# mean absolute percentual error: 0.08

# %% [markdown]
# ### Model Summary

# %%
# Sklearn overview
print('------ Lineare Regression -----')
print('Function from sklearn: y = %.3f * x + %.3f' % (model2.coef_[0], model2.intercept_))
print("Alpha: {}".format(model2.intercept_))
print("Beta: {}".format(model2.coef_[0]))
print("Training Set R² Score: {:.2f}".format(model2.score(X2_train, y2_train)))
print("Test Set R² Score: {:.2f}".format(model2.score(X2_test, y2_test)))
print("\n")
# Out:
# ------ Lineare Regression -----
# Function from sklearn: y = -0.666 * x + 178.742
# Alpha: 178.74159633663038
# Beta: -0.6661784138640019
# Training Set R² Score: 0.51
# Test Set R² Score: 0.51

# %%
# Stats overview
X_train_const_scaled2 = sm.add_constant(X2_train) # adding a constant

model2_OLS = sm.OLS(y2_train, X_train_const_scaled2).fit()
predictions2 = model2_OLS.predict(X_train_const_scaled2) 

X_test_const_scaled2 = sm.add_constant(X2_test) # adding a constant
print_model2 = model2_OLS.summary()
print(print_model2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       target_deathrate   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     87.94
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        16:51:20   Log-Likelihood:                -10704.
# No. Observations:                2442   AIC:                         2.147e+04
# Df Residuals:                    2412   BIC:                         2.164e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                          178.7416      0.395    452.391      0.000     177.967     179.516
# avganncount                     -0.6662      0.463     -1.440      0.150      -1.574       0.241
# incidencerate                   10.5330      0.464     22.704      0.000       9.623      11.443
# medincome                        3.2889      1.099      2.991      0.003       1.133       5.445
# povertypercent                   4.8001      1.134      4.232      0.000       2.576       7.024
# studypercap                      0.0399      0.382      0.104      0.917      -0.709       0.789
# medianage                        0.1200      0.408      0.294      0.769      -0.680       0.920
# medianagemale                   -2.1251      0.915     -2.322      0.020      -3.920      -0.331
# avghouseholdsize                 0.2593      0.447      0.580      0.562      -0.618       1.136
# percentmarried                   6.4037      1.173      5.460      0.000       4.104       8.704
# pctnohs18_24                   -97.4725    111.348     -0.875      0.381    -315.820     120.875
# pcths18_24                    -105.7111    124.782     -0.847      0.397    -350.401     138.979
# pctsomecol18_24               -130.6925    151.175     -0.865      0.387    -427.140     165.755
# pctbachdeg18_24                -54.7559     62.500     -0.876      0.381    -177.314      67.803
# pcths25_over                     3.0666      0.767      3.996      0.000       1.562       4.572
# pctbachdeg25_over               -6.6812      0.932     -7.172      0.000      -8.508      -4.854
# pctemployed16_over              -0.2430      0.489     -0.497      0.619      -1.202       0.716
# pctunemployed16_over             1.0782      0.628      1.716      0.086      -0.154       2.310
# pctprivatecoverage              -4.1081      1.281     -3.207      0.001      -6.620      -1.597
# pctpubliccoverage               -2.3626      1.654     -1.429      0.153      -5.606       0.880
# pctpubliccoveragealone           2.3439      1.697      1.381      0.167      -0.984       5.672
# pctwhite                        -2.0382      1.085     -1.879      0.060      -4.166       0.089
# pctblack                        -1.4277      0.938     -1.522      0.128      -3.267       0.411
# pctasian                        -0.2953      0.544     -0.543      0.587      -1.362       0.771
# pctotherrace                    -3.0699      0.517     -5.936      0.000      -4.084      -2.056
# pctmarriedhouseholds            -7.3792      1.097     -6.726      0.000      -9.531      -5.228
# birthrate                       -2.5437      0.423     -6.015      0.000      -3.373      -1.714
# industry_share_manufacturing     1.2003      0.458      2.623      0.009       0.303       2.097
# industry_share_mineoilgas       -0.0125      0.464     -0.027      0.979      -0.923       0.898
# poppct_urban                    -0.4616      0.618     -0.748      0.455      -1.673       0.749
# ==============================================================================
# Omnibus:                      176.036   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              853.030
# Skew:                           0.116   Prob(JB):                    5.85e-186
# Kurtosis:                       5.886   Cond. No.                     1.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# get coefficient
intercept = model2.intercept_
features = pd.DataFrame(model2.coef_, X2.columns, columns=['coefficient'])
# get standard deviation
stdevs = []
for i in X2.columns:
    stdev = X2[i].std()
    stdevs.append(stdev)
 
features["stdev"] = np.array(stdevs).reshape(-1,1)
features["importance"] = features["coefficient"] * features["stdev"]
features['importance_normalized'] = 100*features['importance'] / features['importance'].max()
plt.barh(features.index, features.importance_normalized)
# Out:
# <BarContainer object of 29 artists>

# %% [markdown]
# ## 4.3 Model 3

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X4_raw = numerical_o.drop(['target_deathrate','ratioemployment','ratiocoverage','uv'], axis=1)
Y4 = numerical_o['target_deathrate']

# Use Standard_Scaler
X4_array = StandardScaler().fit_transform(X4_raw)
X4 = pd.DataFrame(X4_array, index=X4_raw.index, columns=X4_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, Y3, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# set model to Linear Regression
model3=LinearRegression()
# train the model
model3.fit(X3_train, y3_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction, plotting, metrics

# %%
y3_pred=model3.predict(X3_test)   # model prediction
y3_pred

result3=pd.DataFrame({"y_test":y3_test,"y_pred":y3_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y3_pred, y3_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y3_test - y3_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result3, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
# Compute:
# ME: mean error
ME3 = np.mean( y3_test - y3_pred )

# MAE: mean absolute error
MAE3 = np.mean( np.abs( y3_test - y3_pred ) )

# MSE: mean squared error
MSE3 = np.mean( np.power( y3_test - y3_pred , 2 ) )

# RMSE: root mean squared error
RMSE3 = np.sqrt(MSE3)

# MAPE: mean absolute percentual error
MAPE3 = np.mean( np.abs( y3_test - y3_pred) / y3_test ) 

print('mean error: ' + str(round(ME3,2)))
print('mean absolute error: ' + str(round(MAE3,2)))
print('mean squared error: ' + str(round(MSE3,2)))
print('root mean squared error: ' + str(round(RMSE3,2)))
print('mean absolute percentual error: ' + str(round(MAPE3,2)))
# Out:
# mean error: 1.53
# mean absolute error: 11.7
# mean squared error: 247.09
# root mean squared error: 15.72
# mean absolute percentual error: 0.07

# %% [markdown]
# ### Model Summary

# %%
# Sklearn overview
print('------ Lineare Regression -----')
print('Function from sklearn: y = %.3f * x + %.3f' % (model3.coef_[0], model3.intercept_))
print("Alpha: {}".format(model3.intercept_))
print("Beta: {}".format(model3.coef_[0]))
print("Training Set R² Score: {:.2f}".format(model3.score(X3_train, y3_train)))
print("Test Set R² Score: {:.2f}".format(model3.score(X3_test, y3_test)))
print("\n")
# Out:
# ------ Lineare Regression -----
# Function from sklearn: y = -0.364 * x + 2059.264
# Alpha: 2059.264337524869
# Beta: -0.36374549856144717
# Training Set R² Score: 0.66
# Test Set R² Score: 0.66

# %%
# Stats overview
X_train_const_scaled3 = sm.add_constant(X3_train) # adding a constant

model3_OLS = sm.OLS(y3_train, X_train_const_scaled3).fit()
predictions3 = model3_OLS.predict(X_train_const_scaled3) 

X_test_const_scaled3 = sm.add_constant(X3_test) # adding a constant
print_model3 = model3_OLS.summary()
print(print_model3)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       target_deathrate   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.646
# Method:                 Least Squares   F-statistic:                     68.62
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):          5.39e-256
# Time:                        16:51:22   Log-Likelihood:                -5219.3
# No. Observations:                1261   AIC:                         1.051e+04
# Df Residuals:                    1226   BIC:                         1.069e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.4118      0.288      1.430      0.153      -0.153       0.977
# avganncount                     -0.3637      0.020    -18.597      0.000      -0.402      -0.325
# avgdeathsperyear                 0.8314      0.043     19.441      0.000       0.747       0.915
# incidencerate                    0.2450      0.011     21.982      0.000       0.223       0.267
# medincome                        0.0005      0.000      4.300      0.000       0.000       0.001
# popest2015                       0.0002   4.81e-05      4.663      0.000       0.000       0.000
# povertypercent                   1.0759      0.219      4.913      0.000       0.646       1.506
# studypercap                      0.0041      0.007      0.557      0.578      -0.010       0.019
# medianage                        1.4942      1.502      0.995      0.320      -1.452       4.440
# medianagemale                   -1.4010      0.860     -1.629      0.104      -3.088       0.286
# medianagefemale                 -0.1742      0.769     -0.227      0.821      -1.683       1.334
# avghouseholdsize                -5.4255      4.914     -1.104      0.270     -15.067       4.216
# percentmarried                   0.0174      0.246      0.071      0.944      -0.466       0.500
# pctnohs18_24                   -19.8494     14.392     -1.379      0.168     -48.085       8.387
# pcths18_24                     -19.5948     14.394     -1.361      0.174     -47.834       8.645
# pctsomecol18_24                -19.8426     14.394     -1.379      0.168     -48.082       8.397
# pctbachdeg18_24                -19.7412     14.399     -1.371      0.171     -47.991       8.508
# pcths25_over                     0.3188      0.131      2.425      0.015       0.061       0.577
# pctbachdeg25_over               -0.9558      0.218     -4.394      0.000      -1.382      -0.529
# pctemployed16_over              -0.1643      0.086     -1.918      0.055      -0.332       0.004
# pctunemployed16_over             0.5386      0.227      2.371      0.018       0.093       0.984
# pctprivatecoverage              -0.2637      0.236     -1.119      0.263      -0.726       0.199
# pctprivatecoveragealone         -0.3191      0.249     -1.280      0.201      -0.808       0.170
# pctempprivcoverage               0.2989      0.161      1.854      0.064      -0.017       0.615
# pctpubliccoverage               -0.6162      0.313     -1.969      0.049      -1.230      -0.002
# pctpubliccoveragealone           0.7171      0.385      1.860      0.063      -0.039       1.473
# pctwhite                        -0.0351      0.089     -0.396      0.692      -0.209       0.139
# pctblack                        -0.0284      0.093     -0.305      0.760      -0.211       0.154
# pctasian                         1.1093      0.838      1.323      0.186      -0.536       2.754
# pctotherrace                    -1.6970      0.376     -4.515      0.000      -2.434      -0.960
# pctmarriedhouseholds            -0.0739      0.261     -0.283      0.777      -0.585       0.437
# birthrate                       -0.7580      0.277     -2.738      0.006      -1.301      -0.215
# industry_share_manufacturing     0.0577      0.038      1.537      0.125      -0.016       0.131
# industry_share_mineoilgas       -0.1447      0.308     -0.470      0.639      -0.749       0.460
# poppct_urban                    20.5645     14.393      1.429      0.153      -7.672      48.801
# poppct_rural                    20.6126     14.393      1.432      0.152      -7.625      48.850
# ==============================================================================
# Omnibus:                       31.015   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.634
# Skew:                           0.183   Prob(JB):                     2.26e-12
# Kurtosis:                       3.941   Cond. No.                     2.71e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  9e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# get coefficient
intercept = model3.intercept_
features = pd.DataFrame(model3.coef_, X3.columns, columns=['coefficient'])
# get standard deviation
stdevs = []
for i in X3.columns:
    stdev = X3[i].std()
    stdevs.append(stdev)
 
features["stdev"] = np.array(stdevs).reshape(-1,1)
features["importance"] = features["coefficient"] * features["stdev"]
features['importance_normalized'] = 100*features['importance'] / features['importance'].max()
plt.barh(features.index, features.importance_normalized)
# Out:
# <BarContainer object of 35 artists>

# %% [markdown]
# ## 4.4 Model 4

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X4_raw = numerical_o[['avganncount','avgdeathsperyear','incidencerate','medincome','popest2015','povertypercent','pctbachdeg25_over','pctemployed16_over','pctunemployed16_over','pctempprivcoverage','pctpubliccoverage','pctpubliccoveragealone','pctotherrace','birthrate']]
Y4 = numerical_o['target_deathrate']

# Use Standard_Scaler
X4_array = StandardScaler().fit_transform(X4_raw)
X4 = pd.DataFrame(X4_array, index=X4_raw.index, columns=X4_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, Y4, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# set model to Linear Regression
model4=LinearRegression()
# train the model
model4.fit(X4_train, y4_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction, plotting, metrics

# %%
y4_pred=model4.predict(X4_test)   # model prediction
y4_pred

result4=pd.DataFrame({"y_test":y4_test,"y_pred":y4_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y4_pred, y4_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y4_test - y4_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result4, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
# Compute:
# ME: mean error
ME4 = np.mean( y4_test - y4_pred )

# MAE: mean absolute error
MAE4 = np.mean( np.abs( y4_test - y4_pred ) )

# MSE: mean squared error
MSE4 = np.mean( np.power( y4_test - y4_pred , 2 ) )

# RMSE: root mean squared error
RMSE4 = np.sqrt(MSE4)

# MAPE: mean absolute percentual error
MAPE4 = np.mean( np.abs( y4_test - y4_pred) / y4_test ) 

print('mean error: ' + str(round(ME4,2)))
print('mean absolute error: ' + str(round(MAE4,2)))
print('mean squared error: ' + str(round(MSE4,2)))
print('root mean squared error: ' + str(round(RMSE4,2)))
print('mean absolute percentual error: ' + str(round(MAPE4,2)))
# Out:
# mean error: 1.39
# mean absolute error: 11.67
# mean squared error: 244.34
# root mean squared error: 15.63
# mean absolute percentual error: 0.07

# %% [markdown]
# ### Model Summary

# %%
# Sklearn overview
print('------ Lineare Regression -----')
print('Function from sklearn: y = %.3f * x + %.3f' % (model4.coef_[0], model4.intercept_))
print("Alpha: {}".format(model4.intercept_))
print("Beta: {}".format(model4.coef_[0]))
print("Training Set R² Score: {:.2f}".format(model4.score(X4_train, y4_train)))
print("Test Set R² Score: {:.2f}".format(model4.score(X4_test, y4_test)))
print("\n")
# Out:
# ------ Lineare Regression -----
# Function from sklearn: y = -81.551 * x + 181.231
# Alpha: 181.23131763643906
# Beta: -81.55105950726629
# Training Set R² Score: 0.64
# Test Set R² Score: 0.66

# %%
# Stats overview
X_train_const_scaled4 = sm.add_constant(X4_train) # adding a constant

model4_OLS = sm.OLS(y4_train, X_train_const_scaled4).fit()
predictions4 = model4_OLS.predict(X_train_const_scaled4) 

X_test_const_scaled4 = sm.add_constant(X4_test) # adding a constant
print_model4 = model4_OLS.summary()
print(print_model4)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       target_deathrate   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     157.5
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):          1.48e-263
# Time:                        16:51:25   Log-Likelihood:                -5249.0
# No. Observations:                1261   AIC:                         1.053e+04
# Df Residuals:                    1246   BIC:                         1.061e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    181.2313      0.441    411.096      0.000     180.366     182.096
# avganncount              -81.5511      4.242    -19.224      0.000     -89.873     -73.229
# avgdeathsperyear          72.6744      3.554     20.448      0.000      65.702      79.647
# incidencerate             12.2172      0.525     23.281      0.000      11.188      13.247
# medincome                  4.5150      1.111      4.064      0.000       2.336       6.695
# popest2015                 8.2997      2.013      4.124      0.000       4.351      12.248
# povertypercent             5.2578      1.078      4.877      0.000       3.143       7.373
# pctbachdeg25_over         -6.8146      0.706     -9.651      0.000      -8.200      -5.429
# pctemployed16_over        -1.4822      0.649     -2.285      0.022      -2.755      -0.210
# pctunemployed16_over       1.4585      0.619      2.355      0.019       0.243       2.674
# pctempprivcoverage         0.2427      0.822      0.295      0.768      -1.371       1.856
# pctpubliccoverage         -4.1738      1.273     -3.279      0.001      -6.671      -1.677
# pctpubliccoveragealone     5.9517      1.204      4.943      0.000       3.589       8.314
# pctotherrace              -2.6415      0.489     -5.397      0.000      -3.602      -1.681
# birthrate                 -1.2347      0.462     -2.675      0.008      -2.140      -0.329
# ==============================================================================
# Omnibus:                       30.188   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.337
# Skew:                           0.151   Prob(JB):                     9.63e-13
# Kurtosis:                       3.981   Cond. No.                         29.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from sklearn.model_selection import cross_val_score

scores1 = cross_val_score(model4,X=X4_train,y=y4_train, cv=10)
print ('Cross-validated scores:', scores1)
print('score_mean',scores1.mean(),': score_std',scores1.std())
# Out:
# Cross-validated scores: [0.67960904 0.68537217 0.70938194 0.44943232 0.59545682 0.67877206
#  0.63383554 0.48003163 0.59427671 0.56506764]
# score_mean 0.6071235884885986 : score_std 0.08412463594454388

# %%
# get coefficient
intercept = model4.intercept_
features = pd.DataFrame(model4.coef_, X4.columns, columns=['coefficient'])
# get standard deviation
stdevs = []
for i in X4.columns:
    stdev = X4[i].std()
    stdevs.append(stdev)
 
features["stdev"] = np.array(stdevs).reshape(-1,1)
features["importance"] = features["coefficient"] * features["stdev"]
features['importance_normalized'] = 100*features['importance'] / features['importance'].max()
plt.barh(features.index, features.importance_normalized)
# Out:
# <BarContainer object of 14 artists>

# %% [markdown]
# ## 4.5 Model 6

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X = dfnum_bins.drop(['target_deathrateq','uvq','ratioemploymentq','ratiocoverageq'], axis=1)
Y = dfnum['target_deathrate']

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# set model to Linear Regression
model=LinearRegression()
# train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction, Plotting, Metrics

# %%
y_pred=model.predict(X_test)   # model prediction
y_pred

result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
# Compute:
# ME: mean error
ME = np.mean( y_test - y_pred )

# MAE: mean absolute error
MAE = np.mean( np.abs( y_test - y_pred ) )

# MSE: mean squared error
MSE = np.mean( np.power( y_test - y_pred , 2 ) )

# RMSE: root mean squared error
RMSE = np.sqrt(MSE)

# MAPE: mean absolute percentual error
MAPE = np.mean( np.abs( y_test - y_pred) / y_test ) 

print('mean error: ' + str(round(ME,2)))
print('mean absolute error: ' + str(round(MAE,2)))
print('mean squared error: ' + str(round(MSE,2)))
print('root mean squared error: ' + str(round(RMSE,2)))
print('mean absolute percentual error: ' + str(round(MAPE,2)))
# Out:
# mean error: -0.55
# mean absolute error: 14.85
# mean squared error: 397.14
# root mean squared error: 19.93
# mean absolute percentual error: 0.09

# %% [markdown]
# ### Model Summary

# %%
# Sklearn overview
print('------ Lineare Regression -----')
print('Function from sklearn: y = %.3f * x + %.3f' % (model.coef_[0], model.intercept_))
print("Alpha: {}".format(model.intercept_))
print("Beta: {}".format(model.coef_[0]))
print("Training Set R² Score: {:.2f}".format(model.score(X_train, y_train)))
print("Test Set R² Score: {:.2f}".format(model.score(X_test, y_test)))
print("\n")
# Out:
# ------ Lineare Regression -----
# Function from sklearn: y = -1.609 * x + 180.449
# Alpha: 180.4487295508943
# Beta: -1.6089113898800624
# Training Set R² Score: 0.52
# Test Set R² Score: 0.47

# %%
# Stats overview
X_train_const_scaled = sm.add_constant(X_train) # adding a constant

model_OLS = sm.OLS(y_train, X_train_const_scaled).fit()
predictions = model_OLS.predict(X_train_const_scaled) 

X_test_const_scaled = sm.add_constant(X_test) # adding a constant
print_model = model_OLS.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       target_deathrate   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                     78.16
# Date:                Wed, 17 Nov 2021   Prob (F-statistic):               0.00
# Time:                        16:51:27   Log-Likelihood:                -10677.
# No. Observations:                2442   AIC:                         2.142e+04
# Df Residuals:                    2407   BIC:                         2.163e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            32.8089      1.088     30.163      0.000      30.676      34.942
# avganncountq                     -1.6089      0.499     -3.226      0.001      -2.587      -0.631
# avgdeathsperyearq                14.4086      0.959     15.023      0.000      12.528      16.289
# incidencerateq                    6.3267      0.312     20.268      0.000       5.715       6.939
# medincomeq                       -1.5654      0.690     -2.268      0.023      -2.919      -0.212
# popest2015q                     -12.1967      1.018    -11.978      0.000     -14.193     -10.200
# povertypercentq                   0.6060      0.723      0.838      0.402      -0.812       2.024
# studypercapq                     -2.1422      1.090     -1.966      0.049      -4.279      -0.005
# medianageq                       -0.4716      1.117     -0.422      0.673      -2.662       1.719
# medianagemaleq                   -1.1943      0.906     -1.319      0.187      -2.970       0.582
# medianagefemaleq                 -2.0296      0.879     -2.309      0.021      -3.754      -0.306
# avghouseholdsizeq                -0.2516      0.451     -0.558      0.577      -1.136       0.633
# percentmarriedq                   2.4382      0.650      3.749      0.000       1.163       3.714
# pctnohs18_24q                    -0.4080      0.479     -0.853      0.394      -1.346       0.530
# pcths18_24q                       1.8421      0.518      3.558      0.000       0.827       2.857
# pctsomecol18_24q                  0.2707      0.578      0.468      0.640      -0.864       1.405
# pctbachdeg18_24q                 -1.2278      0.403     -3.044      0.002      -2.019      -0.437
# pcths25_overq                     1.9839      0.468      4.237      0.000       1.066       2.902
# pctbachdeg25_overq               -2.0858      0.547     -3.810      0.000      -3.159      -1.012
# pctemployed16_overq              -0.1273      0.490     -0.260      0.795      -1.088       0.833
# pctunemployed16_overq             1.2375      0.427      2.898      0.004       0.400       2.075
# pctprivatecoverageq              -2.7531      0.883     -3.117      0.002      -4.485      -1.021
# pctprivatecoveragealoneq         -1.3693      0.958     -1.430      0.153      -3.247       0.508
# pctempprivcoverageq               1.6007      0.728      2.200      0.028       0.174       3.027
# pctpubliccoverageq               -1.8279      0.796     -2.297      0.022      -3.388      -0.267
# pctpubliccoveragealoneq           0.6103      0.790      0.772      0.440      -0.939       2.160
# pctwhiteq                         0.1748      0.549      0.318      0.750      -0.902       1.252
# pctblackq                         1.3533      0.484      2.794      0.005       0.403       2.303
# pctasianq                        -0.1297      0.415     -0.312      0.755      -0.944       0.684
# pctotherraceq                    -1.5631      0.362     -4.322      0.000      -2.272      -0.854
# pctmarriedhouseholdsq            -3.1654      0.615     -5.148      0.000      -4.371      -1.960
# birthrateq                       -0.6834      0.301     -2.272      0.023      -1.273      -0.094
# industry_share_manufacturingq     0.4428      0.326      1.356      0.175      -0.197       1.083
# industry_share_mineoilgasq        0.4641      0.298      1.556      0.120      -0.121       1.049
# poppct_urbanq                    48.1224      1.664     28.912      0.000      44.859      51.386
# poppct_ruralq                    50.3041      1.647     30.543      0.000      47.075      53.534
# ==============================================================================
# Omnibus:                      198.669   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              840.473
# Skew:                           0.285   Prob(JB):                    3.12e-183
# Kurtosis:                       5.817   Cond. No.                     8.41e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.68e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# get coefficient
intercept = model.intercept_
features = pd.DataFrame(model.coef_, X.columns, columns=['coefficient'])
# get standard deviation
stdevs = []
for i in X.columns:
    stdev = X[i].std()
    stdevs.append(stdev)
 
features["stdev"] = np.array(stdevs).reshape(-1,1)
features["importance"] = features["coefficient"] * features["stdev"]
features['importance_normalized'] = 100*features['importance'] / features['importance'].max()
plt.barh(features.index, features.importance_normalized)
# Out:
# <BarContainer object of 35 artists>

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Model 5

# %%
from sklearn.ensemble import RandomForestRegressor

# Split-Up numerical into X and Y
X5 = numerical_o.drop(['target_deathrate','ratioemployment','ratiocoverage','uv'], axis=1)
Y5 = numerical_o['target_deathrate']

# train-test-split
X5_train, X5_test, y5_train, y5_test = train_test_split(X5, Y5, test_size=0.20)

# Train Random Forest
rf5 = RandomForestRegressor(n_estimators=100)
rf5.fit(X5_train, y5_train)

y5_pred=rf5.predict(X5_test)   # model prediction


print("Training set score: {:.2f}".format(rf5.score(X5_train, y5_train)))
print("Test set score: {:.2f}".format(rf5.score(X5_test, y5_test)))

fig = plt.figure()
ax = fig.add_subplot(111)

ax.errorbar(y5_test, y5_pred, fmt='o')
ax.errorbar([1, y5_test.max()], [1, y5_test.max()])
# Out:
# Training set score: 0.93
# Test set score: 0.59
# <ErrorbarContainer object of 3 artists>

# %%
# building graph for the important features
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# calculating the most important features
sorted_idx = rf5.feature_importances_.argsort()
plt.barh(X5.columns[sorted_idx], rf5.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

scores1 = cross_val_score(rf5,X=X5_train,y=y5_train, cv=10)
print ('Cross-validated scores:', scores1)
print('score_mean',scores1.mean(),': score_std',scores1.std())
# Out:
# Cross-validated scores: [0.35135269 0.57885087 0.44366441 0.54605107 0.50207523 0.30332652
#  0.57246711 0.43814058 0.55442985 0.58340613]
# score_mean 0.48737644375462896 : score_std 0.09470816565807881

# %% [markdown]
# ## Model 7

# %% [markdown]
# ### Exclude outliers from dependent variable

# %%
df6=reduced_df[(reduced_df['target_deathrate']>reduced_df['target_deathrate'].quantile(0.25)-(1.5*(st.iqr(reduced_df['target_deathrate']))))&(reduced_df['target_deathrate']<reduced_df['target_deathrate'].quantile(0.75)+(1.5*(st.iqr(reduced_df['target_deathrate']))))]

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X_raw = df6.drop(['target_deathrate','ratioemployment','ratiocoverage','uv'], axis=1)
Y = df6['target_deathrate']

# Use Standard_Scaler
X_array = StandardScaler().fit_transform(X_raw)
X = pd.DataFrame(X_array, index=X_raw.index, columns=X_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# linear regression but this time with stats
import statsmodels.api as sm
modelOLS = sm.OLS(list(y_train),sm.add_constant(X_train)).fit()
# Out:
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# ### Identify significant features with p-values

# %%
features=[]
a=modelOLS.pvalues
for i in range(a.shape[0]):
    if  a[i]<0.05:
        features.append(a.index[i])
    else:
        continue
print(features)
# Out:
# ['const', 'avganncount', 'incidencerate', 'medianagemale', 'percentmarried', 'pcths25_over', 'pctbachdeg25_over', 'pctemployed16_over', 'pctunemployed16_over', 'pctprivatecoverage', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate', 'industry_share_manufacturing']

# %%
# new X
X = df6[['incidencerate', 'medincome', 'povertypercent', 'medianagemale', 'percentmarried', 'pcths25_over', 'pctbachdeg25_over', 'pctprivatecoverage', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate', 'industry_share_manufacturing']]

# %% [markdown]
# ### Check for features that are not normaly distributed

# %%
import scipy.stats as st

nor=[]
for i in  X.columns:
    if st.shapiro(X[i])[1]<0.05:
        nor.append(i)
    else:
        continue
print(nor)
# Out:
# ['incidencerate', 'medincome', 'povertypercent', 'medianagemale', 'percentmarried', 'pcths25_over', 'pctbachdeg25_over', 'pctprivatecoverage', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate', 'industry_share_manufacturing']

# %%
# write them into a new column for transforming
to_transform=X[['incidencerate', 'medincome', 'povertypercent', 'medianagemale', 'percentmarried', 'pcths25_over', 'pctbachdeg25_over', 'pctprivatecoverage', 'pctotherrace', 'pctmarriedhouseholds', 'birthrate', 'industry_share_manufacturing']]

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
X_train.min()
# Out:
# incidencerate                     201.30000
# medincome                       22640.00000
# povertypercent                      3.20000
# medianagemale                      22.80000
# percentmarried                     23.10000
# pcths25_over                        7.50000
# pctbachdeg25_over                   2.70000
# pctprivatecoverage                 22.30000
# pctotherrace                        0.00000
# pctmarriedhouseholds               22.99249
# birthrate                           0.00000
# industry_share_manufacturing        0.00000
# dtype: float64

# %% [markdown]
# ### New Model

# %%
# set model to Linear Regression
model=LinearRegression()
# train the model
model.fit(X_train, y_train)

# Results
print('r2 score for train data :',model.score(X_train, y_train))
print('r2 score for test data :',model.score(X_test, y_test))
# Out:
# r2 score for train data : 0.4706272521731011
# r2 score for test data : 0.426180415338794

# %% [markdown]
# ### Polynominal features

# %%
# Importing and running Polynominal features
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2) 
X_poly = poly.fit_transform(X) 

# Do new train-test-split with poly features  
X_train, X_test , y_train, y_test = train_test_split(X_poly,Y, test_size = 0.20, random_state = 42)

# %% [markdown]
# ### Linear regression

# %%
model2 = LinearRegression() 
model2.fit(X_train,y_train) 

#r2 for the train data
print('r2 score for train data :',model2.score(X_train, y_train))

#r2 for the test data
print('r2 score for test data :',model2.score(X_test, y_test))
# Out:
# r2 score for train data : 0.5481401988821959
# r2 score for test data : 0.358610212748551

# %% [markdown]
# ### Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

scores1 = cross_val_score(model2,X=X_train,y=y_train, cv=10)
print ('Cross-validated scores:', scores1)
print('score_mean',scores1.mean(),': score_std',scores1.std())
# Out:
# Cross-validated scores: [0.32732759 0.2447818  0.34578186 0.25201533 0.28993357 0.2621
#  0.1987511  0.21600147 0.29930568 0.16101415]
# score_mean 0.2597012544619196 : score_std 0.054878819662576524

# %% [markdown]
# ## 5. Cancer incidences as dependent variable

# %% [markdown]
# ### Clean Data

# %%
# Delete Alaska and Hawaii as the UV numbers are missing in the UV column
print(data_main.shape)
data_main.drop(data_main[data_main['state_short'] == 'AK'].index, inplace = True)
data_main.drop(data_main[data_main['state_short'] == 'HI'].index, inplace = True)
print(data_main.shape)
# Out:
# (3031, 45)
# (3031, 45)

# %% [markdown]
# ### Outliners

# %%
# Seperate the numerical numbers
numerical_incidence = data_main.select_dtypes('number')

# check IRQ
Q1 = numerical_incidence.quantile(0.25)
Q3 = numerical_incidence.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# avganncount                       445.000000
# avgdeathsperyear                  121.500000
# target_deathrate                   33.950000
# incidencerate                      60.100000
# medincome                       13543.500000
# popest2015                      56984.500000
# povertypercent                      8.200000
# studypercap                        83.811121
# medianage                           6.200000
# medianagemale                       6.200000
# medianagefemale                     6.300000
# avghouseholdsize                    0.260000
# percentmarried                      8.600000
# pctnohs18_24                        9.900000
# pcths18_24                         11.450000
# pctsomecol18_24                    12.700000
# pctbachdeg18_24                     5.200000
# pcths25_over                        9.300000
# pctbachdeg25_over                   6.700000
# pctemployed16_over                 12.000000
# pctunemployed16_over                4.200000
# pctprivatecoverage                 14.900000
# pctprivatecoveragealone            14.524686
# pctempprivcoverage                 13.200000
# pctpubliccoverage                  10.700000
# pctpubliccoveragealone              8.200000
# pctwhite                           17.882861
# pctblack                           10.114116
# pctasian                            0.953204
# pctotherrace                        1.888409
# pctmarriedhouseholds                7.629854
# birthrate                           1.960466
# industry_share_manufacturing       17.183190
# industry_share_mineoilgas           1.750254
# uv                                612.000000
# poppct_urban                       51.700000
# poppct_rural                       51.700000
# ratioemployment                     3.225038
# ratiocoverage                       0.056705
# dtype: float64

# %%
# Count the outliers for each column

((numerical_incidence < (Q1 - 1.5 * IQR)) | (numerical_incidence > (Q3 + 1.5 * IQR))).sum()
# Out:
# avganncount                     461
# avgdeathsperyear                348
# target_deathrate                 62
# incidencerate                    94
# medincome                       117
# popest2015                      411
# povertypercent                   70
# studypercap                     501
# medianage                        94
# medianagemale                    82
# medianagefemale                  65
# avghouseholdsize                190
# percentmarried                   70
# pctnohs18_24                     68
# pcths18_24                       51
# pctsomecol18_24                 114
# pctbachdeg18_24                  88
# pcths25_over                     29
# pctbachdeg25_over                83
# pctemployed16_over               45
# pctunemployed16_over             64
# pctprivatecoverage               19
# pctprivatecoveragealone           5
# pctempprivcoverage                9
# pctpubliccoverage                15
# pctpubliccoveragealone           35
# pctwhite                        166
# pctblack                        381
# pctasian                        324
# pctotherrace                    295
# pctmarriedhouseholds            100
# birthrate                       163
# industry_share_manufacturing     88
# industry_share_mineoilgas       553
# uv                               31
# poppct_urban                      0
# poppct_rural                      0
# ratioemployment                 253
# ratiocoverage                   298
# dtype: int64

# %%
# Delete Outliers from dependent variable as they are only 3% of sample size

df7=numerical_incidence[(numerical_incidence['incidencerate']>numerical_incidence['incidencerate'].quantile(0.25)-(1.5*(st.iqr(numerical_incidence['incidencerate']))))&(numerical_incidence['incidencerate']<numerical_incidence['incidencerate'].quantile(0.75)+(1.5*(st.iqr(numerical_incidence['incidencerate']))))]

# %%
df7
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3048  1962.667684                15             149.6     453.549422
# 3049  1962.667684                43             150.1     453.549422
# 3050  1962.667684                46             153.9     453.549422
# 3051  1962.667684                52             175.0     453.549422
# 3052  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap  medianage  \
# 0         61898      260131            11.2   499.748204       39.3
# 1         48127       43269            18.6    23.111234       33.0
# 2         49348       21026            14.6    47.560164       45.0
# 3         44243       75882            17.1   342.637253       42.8
# 4         49955       10321            12.5     0.000000       48.3
# ...         ...         ...             ...          ...        ...
# 3048      46961        6343            12.4     0.000000       44.2
# 3049      48609       37118            18.8   377.175494       30.4
# 3050      51144       34536            15.0  1968.959926       30.9
# 3051      50745       25609            13.3     0.000000       39.0
# 3052      41193       37030            13.9     0.000000       26.2
#
#       medianagemale  ...  pctotherrace  pctmarriedhouseholds  birthrate  \
# 0              36.9  ...      1.843479             52.856076   6.118831
# 1              32.2  ...      3.741352             45.372500   4.333096
# 2              44.0  ...      2.747358             54.444868   3.729488
# 3              42.2  ...      1.362643             51.021514   4.603841
# 4              47.8  ...      0.492135             54.027460   6.796657
# ...             ...  ...           ...                   ...        ...
# 3048           41.1  ...      1.700468             51.063830   7.773512
# 3049           29.3  ...     14.130288             52.007937   8.186470
# 3050           30.5  ...      5.680705             55.153949   7.809192
# 3051           36.9  ...      2.131790             58.484232   7.582938
# 3052           25.5  ...      1.356457             56.040242   8.981723
#
#       industry_share_manufacturing  industry_share_mineoilgas      uv  \
# 0                         2.542714                   0.050196  3244.0
# 1                         3.068327                   0.006207  3806.0
# 2                        18.080733                   0.098422  4051.0
# 3                        10.155325                   1.170562  3425.0
# 4                         0.000000                   0.326622  3870.0
# ...                            ...                        ...     ...
# 3048                     15.817909                   3.937987  4581.0
# 3049                     21.138494                   2.354351  4873.0
# 3050                     31.452893                   0.308944  4848.0
# 3051                     12.407903                   0.694306  4322.0
# 3052                      2.724209                   0.003446  4391.0
#
#       poppct_urban  poppct_rural  ratioemployment  ratiocoverage
# 0            83.26         16.74         5.829581       1.208875
# 1            59.94         40.06         5.829581       1.208875
# 2            39.79         60.21         5.829581       1.208875
# 3            39.35         60.65         5.829581       1.208875
# 4             0.00        100.00         5.829581       1.208875
# ...            ...           ...              ...            ...
# 3048         45.90         54.10        13.217273       1.226752
# 3049         81.42         18.58        13.217273       1.226752
# 3050         80.70         19.30        13.217273       1.226752
# 3051         47.90         52.10        13.217273       1.226752
# 3052         88.33         11.67        13.217273       1.226752
#
# [2937 rows x 39 columns]

# %% [markdown]
# ### Kick out highly correlating columns

# %%
# Create correlation matrix
corr_df = df7.corr().abs()
# Select upper traingular
upper_tri = corr_df.where(np.triu(np.ones(corr_df.shape),k=1).astype(np.bool_))
# Save highly correlating features r>0.9 in the list to_drop
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
# Drop the features from the to_drop list and create a reduced DataFrame
reduced_df7 = df7.drop(df7[to_drop], axis=1)

print("The reduced dataframe has {} columns.".format(reduced_df7.shape[1]))
# Out:
# The reduced dataframe has 33 columns.

# %% [markdown]
# ### Create Bins to deal with outliers without reducing the sample size to much

# %%
df7_bins = pd.DataFrame()
for i, column in enumerate(reduced_df7):
    df7_bins[column] = pd.qcut(reduced_df7[column],5,duplicates='drop',labels=False)
print (df7_bins)
# Out:
#       avganncount  target_deathrate  incidencerate  medincome  povertypercent  \
# 0               4                 1              4          4               0
# 1               2                 1              0          3               3
# 2               1                 2              0          3               2
# 3               3                 3              1          2               2
# 4               0                 0              0          3               1
# ...           ...               ...            ...        ...             ...
# 3048            4                 0              2          2               1
# 3049            4                 0              2          3               3
# 3050            4                 0              2          3               2
# 3051            4                 2              2          3               1
# 3052            4                 4              2          1               1
#
#       studypercap  medianage  medianagemale  avghouseholdsize  percentmarried  \
# 0               1          1              1                 2               2
# 1               0          0              0                 0               0
# 2               0          4              4                 3               3
# 3               1          3              3                 2               2
# 4               0          4              4                 0               4
# ...           ...        ...            ...               ...             ...
# 3048            0          3              3                 0               1
# 3049            1          0              0                 4               2
# 3050            1          0              0                 4               3
# 3051            0          1              1                 3               4
# 3052            0          0              0                 4               4
#
#       ...  pctasian  pctotherrace  pctmarriedhouseholds  birthrate  \
# 0     ...         4             3                     2          3
# 1     ...         4             4                     0          1
# 2     ...         2             4                     3          0
# 3     ...         3             3                     2          1
# 4     ...         2             1                     3          3
# ...   ...       ...           ...                   ...        ...
# 3048  ...         1             3                     2          4
# 3049  ...         4             4                     2          4
# 3050  ...         3             4                     3          4
# 3051  ...         1             3                     4          4
# 3052  ...         4             3                     3          4
#
#       industry_share_manufacturing  industry_share_mineoilgas  uv  \
# 0                                0                          1   0
# 1                                1                          1   0
# 2                                3                          1   1
# 3                                2                          3   0
# 4                                0                          2   0
# ...                            ...                        ...  ..
# 3048                             3                          4   3
# 3049                             3                          3   4
# 3050                             4                          2   4
# 3051                             2                          3   2
# 3052                             0                          0   2
#
#       poppct_urban  ratioemployment  ratiocoverage
# 0                3                1              3
# 1                2                1              3
# 2                1                1              3
# 3                1                1              3
# 4                0                1              3
# ...            ...              ...            ...
# 3048             1                4              4
# 3049             3                4              4
# 3050             3                4              4
# 3051             1                4              4
# 3052             3                4              4
#
# [2937 rows x 33 columns]

# %%
df7_bins.isna().sum()
# Out:
# avganncount                     0
# target_deathrate                0
# incidencerate                   0
# medincome                       0
# povertypercent                  0
# studypercap                     0
# medianage                       0
# medianagemale                   0
# avghouseholdsize                0
# percentmarried                  0
# pctnohs18_24                    0
# pcths18_24                      0
# pctsomecol18_24                 0
# pctbachdeg18_24                 0
# pcths25_over                    0
# pctbachdeg25_over               0
# pctemployed16_over              0
# pctunemployed16_over            0
# pctprivatecoverage              0
# pctpubliccoverage               0
# pctpubliccoveragealone          0
# pctwhite                        0
# pctblack                        0
# pctasian                        0
# pctotherrace                    0
# pctmarriedhouseholds            0
# birthrate                       0
# industry_share_manufacturing    0
# industry_share_mineoilgas       0
# uv                              0
# poppct_urban                    0
# ratioemployment                 0
# ratiocoverage                   0
# dtype: int64

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X1_raw = reduced_df7.drop(['incidencerate','ratioemployment','ratiocoverage','uv'], axis=1)
Y1 = reduced_df7['incidencerate']

# Use Standard_Scaler
X1_array = StandardScaler().fit_transform(X1_raw)
X1 = pd.DataFrame(X1_array, index=X1_raw.index, columns=X1_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.20, random_state=42)

# %% [markdown]
# ### Model

# %%
# set model to Linear Regression
model=LinearRegression()
# train the model
model.fit(X_train, y_train)

# Results
print('r2 score for train data :',model.score(X_train, y_train))
print('r2 score for test data :',model.score(X_test, y_test))
# Out:
# r2 score for train data : 0.3346729046882245
# r2 score for test data : 0.3438933462712963

# %%
y_pred=model.predict(X_test)   # model prediction
y_pred

result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# ### Identify significant features

# %%
# linear regression but this time with stats
import statsmodels.api as sm
modelOLS = sm.OLS(list(y_train),sm.add_constant(X_train)).fit()
# Out:
# C:\Users\flanc\.conda\envs\iron\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
features=[]
a=modelOLS.pvalues
for i in range(a.shape[0]):
    if  a[i]<0.05:
        features.append(a.index[i])
    else:
        continue
print(features)
# Out:
# ['const', 'avganncount', 'target_deathrate', 'medincome', 'avghouseholdsize', 'pctunemployed16_over', 'pctprivatecoverage', 'pctpubliccoveragealone', 'pctotherrace', 'pctmarriedhouseholds', 'industry_share_manufacturing', 'industry_share_mineoilgas', 'poppct_urban']

# %%
#Keep only significant features plus dependent feature
df7_n = df7[['incidencerate','avganncount', 'target_deathrate', 'medincome', 'avghouseholdsize', 'pctunemployed16_over', 'pctprivatecoverage', 'pctpubliccoveragealone', 'pctotherrace', 'pctmarriedhouseholds', 'industry_share_manufacturing', 'industry_share_mineoilgas', 'poppct_urban']]

# %% [markdown]
# ### redo outlier check

# %%
# check IRQ
Q1 = df7_n.quantile(0.25)
Q3 = df7_n.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# incidencerate                      57.300000
# avganncount                       469.000000
# target_deathrate                   33.400000
# medincome                       13396.000000
# avghouseholdsize                    0.260000
# pctunemployed16_over                4.100000
# pctprivatecoverage                 14.700000
# pctpubliccoveragealone              8.100000
# pctotherrace                        1.882006
# pctmarriedhouseholds                7.580224
# industry_share_manufacturing       17.320834
# industry_share_mineoilgas           1.642734
# poppct_urban                       50.830000
# dtype: float64

# %%
# count number of outliers 

((df7_n < (Q1 - 2 * IQR)) | (df7_n > (Q3 + 2 * IQR))).sum()
# Out:
# incidencerate                     0
# avganncount                     409
# target_deathrate                 15
# medincome                        66
# avghouseholdsize                123
# pctunemployed16_over             35
# pctprivatecoverage                5
# pctpubliccoveragealone            9
# pctotherrace                    218
# pctmarriedhouseholds             42
# industry_share_manufacturing     32
# industry_share_mineoilgas       490
# poppct_urban                      0
# dtype: int64

# %%
# cut columns avganncount & industry_share_mineoilgas
df7_n = df7_n.drop(['avganncount','industry_share_mineoilgas'], axis=1)

# %%
# Let's do it again
# check IRQ
Q1 = df7_n.quantile(0.25)
Q3 = df7_n.quantile(0.75)
IQR = Q3 - Q1
((df7_n < (Q1 - 1.5 * IQR)) | (df7_n > (Q3 + 1.5 * IQR))).sum()
# Out:
# incidencerate                    23
# target_deathrate                 50
# medincome                       115
# avghouseholdsize                176
# pctunemployed16_over             64
# pctprivatecoverage               19
# pctpubliccoveragealone           34
# pctotherrace                    282
# pctmarriedhouseholds             94
# industry_share_manufacturing     84
# poppct_urban                      0
# dtype: int64

# %%
# Exclude outliers from all independent features left

df7_o = df7_n[~((df7_n < (Q1 - 1.5 * IQR)) |(df7_n > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df7_n.shape)
print(df7_o.shape)
# Out:
# (2937, 11)
# (2233, 11)

# %% [markdown]
# ### X-Y-Split

# %%
# Split-Up numerical into X and Y
X_raw = df7_o.drop(['incidencerate'], axis=1)
Y = df7_o['incidencerate']

# Use Standard_Scaler
X_array = StandardScaler().fit_transform(X_raw)
X = pd.DataFrame(X_array, index=X_raw.index, columns=X_raw.columns)

# %% [markdown]
# ### Train-Test-Split

# %%
# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# ### New Model

# %%
# set model to Linear Regression
model=LinearRegression()
# train the model
model.fit(X_train, y_train)

# Results
print('r2 score for train data :',model.score(X_train, y_train))
print('r2 score for test data :',model.score(X_test, y_test))
# Out:
# r2 score for train data : 0.27222216578333513
# r2 score for test data : 0.1759816898044836

# %%
y_pred=model.predict(X_test)   # model prediction
y_pred

result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>
